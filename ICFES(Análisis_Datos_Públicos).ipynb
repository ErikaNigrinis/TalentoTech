# %% [markdown]
# <a href="https://colab.research.google.com/github/ErikaNigrinis/TalentoTech/blob/main/ICFES(An%C3%A1lisis_Datos_P%C3%BAblicos).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # La Importancia de la Limpieza, Normalización y Estandarización en la Ciencia de Datos: Un Análisis Detallado

# %% [markdown]
# En el ámbito de la ciencia de datos, las técnicas de limpieza, normalización y estandarización no solo representan pasos esenciales en el preprocesamiento de datos, sino que también constituyen pilares fundamentales para la obtención de resultados precisos y confiables. Estas técnicas, a menudo subestimadas, son cruciales para garantizar la calidad e integridad de los datos, elementos que determinan en gran medida el éxito de cualquier análisis o modelo de aprendizaje automático.

# %% [markdown]
# ![fondo_cleam.png](data:image/png;base64,...)

# %% [markdown]
# 1. Mejora de la Calidad de los Datos:
#     - Limpieza de Datos: Eliminar valores faltantes, duplicados o anómalos mejora la calidad y fiabilidad de los datos, lo que reduce el riesgo de obtener resultados sesgados o incorrectos.
#     - Normalización y Estandarización: Al escalar o transformar las características, facilitamos la interpretación de los datos y mejoramos la convergencia de los algoritmos, lo que resulta en modelos más precisos y robustos.
#
# 2. Facilita el Análisis Exploratorio:
#     - Al limpiar y preparar adecuadamente los datos, es más fácil realizar un análisis exploratorio que proporcione insights y entendimiento sobre los patrones, tendencias y relaciones en los datos.
#
# 3. Preparación para Modelos de Aprendizaje Automático:
#     - Normalización y Estandarización: Los algoritmos de aprendizaje automático, como la regresión logística o las máquinas de soporte vectorial, pueden ser sensibles a la escala de las características. Normalizar o estandarizar los datos ayuda a estos modelos a converger más rápido y a tener un mejor rendimiento.
#
#     - Limpieza de Datos: Los modelos de aprendizaje automático pueden ser afectados negativamente por datos faltantes o anómalos. Por lo tanto, es crucial tratar estos problemas antes de entrenar un modelo.
#
# 4. Aumento de la Reproducibilidad y Fiabilidad:
#     - Al aplicar técnicas sistemáticas de limpieza y transformación, se aumenta la reproducibilidad de los análisis y se obtienen resultados más confiables y consistentes.
#
# 5. Reducción del Tiempo y Costo de Análisis:
#     - La limpieza y preparación adecuada de los datos reducen la necesidad de correcciones posteriores y ajustes en los modelos, lo que ahorra tiempo y recursos en el proceso de análisis de datos.
#
# 6. Mejora la Visualización y Comunicación de Resultados:
#     - Con datos limpios y bien preparados, las visualizaciones resultantes son más claras e interpretables, facilitando la comunicación de los resultados a stakeholders o audiencias no técnicas.
#
# En resumen, las técnicas de limpieza, normalización y estandarización son esenciales en la ciencia de datos porque aseguran la calidad, fiabilidad y interpretabilidad de los datos, preparándolos para análisis avanzados y modelos de aprendizaje automático. Al aplicar estas técnicas de manera adecuada, podemos obtener insights más precisos, modelos más robustos y resultados más confiables, impulsando así la toma de decisiones basada en datos en diversos campos y aplicaciones.

# %% [markdown]
# Recomendaciones y consejos para llevar a cabo una buena limpieza, estandarización y normalización de datos:
#
# 1. Entender el Contexto y los Datos: Antes de comenzar, es crucial comprender el contexto y la naturaleza de los datos. Conocer el dominio del problema y las características de los datos te ayudará a tomar decisiones más informadas durante el proceso de limpieza y transformación.
#
# 2. Identificar y Tratar Datos Faltantes: Detecta y decide cómo tratar los valores faltantes (eliminarlos, imputarlos, etc.) según el tipo de datos y el impacto en el análisis posterior.
#
# 3. Manejar Datos Anómalos o Erróneos: Identifica y corrige los datos anómalos o erróneos que puedan afectar la calidad de los análisis. Utiliza técnicas como el filtrado estadístico o la corrección basada en reglas.
#
# 4. Estandarizar y Normalizar Características: Aplica técnicas de estandarización y normalización para escalar las características y asegurar que todas tengan un rango similar, facilitando así la convergencia de los modelos y la interpretación de los datos.
#
# 5. Verificar la Distribución de Datos: Realiza visualizaciones y estadísticas descriptivas para verificar la distribución de los datos antes y después de la limpieza y transformación. Esto te ayudará a asegurar que los datos se han procesado adecuadamente.
#
# 6. Utilizar Herramientas y Librerías Apropiadas: Familiarízate con herramientas y librerías de Python como pandas, scikit-learn o NumPy que ofrecen funciones y métodos específicos para limpieza, estandarización y normalización de datos.
#
# 7. Documentar el Proceso de Limpieza y Transformación: Documenta cada paso del proceso de limpieza y transformación, incluyendo decisiones tomadas, métodos aplicados y cambios realizados. Esto facilitará la reproducibilidad y comprensión del análisis.
#
# 8. Validar los Resultados con Métricas y Visualizaciones: Utiliza métricas estadísticas y visualizaciones para validar los resultados obtenidos después de la limpieza y transformación. Compara las distribuciones, varianzas y otras características relevantes antes y después del procesamiento.
#
# 9. Considerar el Impacto en el Análisis Posterior: Piensa en cómo las decisiones de limpieza, estandarización y normalización afectarán el análisis y los modelos posteriores. Asegúrate de que las transformaciones sean adecuadas para los algoritmos y técnicas de análisis que planeas utilizar.
#
# 10. Revisar y Actualizar Regularmente: La limpieza y transformación de datos no es un proceso único. Revisa y actualiza regularmente los datos, especialmente si provienen de fuentes en constante cambio, para mantener su calidad y relevancia a lo largo del tiempo.

# %% [markdown]
# # Preparación y configuración del entorno de trabajo

# %% [markdown]
# ## Conexión y consulta a la fuente de datos

# %%
# Importar librerias

import os
import altair as alt
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# !pip install pyodbc
import warnings
import sqlite3
# Out:
# Collecting pyodbc
#   Downloading pyodbc-5.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading pyodbc-5.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.0/336.0 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: pyodbc
# Successfully installed pyodbc-5.2.0

# %%
try:
    # Leer el archivo CSV ubicado en la ruta especificada y asigna los datos a la variable df_resultados
    df_acumulado_saber_11 = pd.read_csv('/content/acumulado_saber_11.csv')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("El dataset se cargó exitosa")

# Si se produce un error específico de "FileNotFoundError" (archivo no encontrado), ejecuta este bloque de código
except FileExistsError as e:

    # Imprime un mensaje de error personalizado indicando que el archivo no se pudo encontrar, junto con los detalles específicos del error
    print(f"Error: El archivo no se puede encontrar. Detalles: {e}")

# Si se produce cualquier otro tipo de error, ejecuta este bloque de código
except Exception as e:

    # Imprime un mensaje de error genérico indicando que ocurrió un error inesperado, junto con los detalles específicos del error
    print(f"Error inesperado: {e}")
# Out:
# El dataset se cargó exitosa

# %%
# Se crea un DataFrame nuevo, utilizando los datos existentes del dataset
df_acumulado_saber_11 = pd.DataFrame(df_acumulado_saber_11)

# Consulta y validación de la cantidad de filas y columnas del dataframe
num_rows, num_cols = df_acumulado_saber_11.shape

# Imprimir mensaje y valores de salidas del dataframe
print(f'El Dataframe, tiene {num_rows} filas {num_cols} columnas.')
# Out:
# El Dataframe, tiene 413002 filas 40 columnas.

# %%
# La función sample, devuelve la cantidad aleatorias de filas/registros solicitada del dataframe
df_acumulado_saber_11.sample(10)
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 235231                 CC          COLOMBIA           M
# 141079                 TI          COLOMBIA           M
# 112248                 TI          COLOMBIA           M
# 357148                 CC          COLOMBIA           F
# 200971                 TI          COLOMBIA           M
# 313401                 CC          COLOMBIA           F
# 11270                  TI          COLOMBIA           M
# 175187                 TI          COLOMBIA           F
# 370998                 TI          COLOMBIA           F
# 57371                  TI          COLOMBIA           F
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# 235231  09/30/1999 12:00:00 AM    20194  SB11201940576247         COLOMBIA
# 141079  02/25/2002 12:00:00 AM    20194  SB11201940076020         COLOMBIA
# 112248  08/20/2001 12:00:00 AM    20194  SB11201940523494         COLOMBIA
# 357148  03/04/2000 12:00:00 AM    20194  SB11201940475539         COLOMBIA
# 200971  08/15/2000 12:00:00 AM    20194  SB11201940221365         COLOMBIA
# 313401  11/25/2000 12:00:00 AM    20194  SB11201940499255         COLOMBIA
# 11270               22/11/1999    20181  SB11201810001696         COLOMBIA
# 175187  09/13/2002 12:00:00 AM    20194  SB11201940271458         COLOMBIA
# 370998  05/04/2003 12:00:00 AM    20194  SB11201940436908         COLOMBIA
# 57371   12/21/2002 12:00:00 AM    20194  SB11201940138993         COLOMBIA
#
#        ESTU_TIENEETNIA ESTU_DEPTO_RESIDE          ESTU_MCPIO_RESIDE  ...  \
# 235231              No         ANTIOQUIA                     ITAGÜÍ  ...
# 141079              No            BOGOTÁ                BOGOTÁ D.C.  ...
# 112248              Si             CAUCA                     CALOTO  ...
# 357148              No            BOGOTÁ                BOGOTÁ D.C.  ...
# 200971              No         ATLANTICO               BARRANQUILLA  ...
# 313401              No         ANTIOQUIA                   CAUCASIA  ...
# 11270               No           QUINDIO                    ARMENIA  ...
# 175187              No         ANTIOQUIA  SAN PEDRO DE LOS MILAGROS  ...
# 370998              No              META                    ACACÍAS  ...
# 57371               No      CUNDINAMARCA                     SOACHA  ...
#
#             COLE_CARACTER COLE_AREA_UBICACION COLE_JORNADA  \
# 235231  TÉCNICO/ACADÉMICO              URBANO        NOCHE
# 141079          ACADÉMICO              URBANO       MAÑANA
# 112248            TÉCNICO               RURAL       MAÑANA
# 357148          ACADÉMICO              URBANO     SABATINA
# 200971          ACADÉMICO              URBANO        UNICA
# 313401  TÉCNICO/ACADÉMICO              URBANO     SABATINA
# 11270           ACADÉMICO               RURAL     COMPLETA
# 175187  TÉCNICO/ACADÉMICO              URBANO     COMPLETA
# 370998  TÉCNICO/ACADÉMICO              URBANO        TARDE
# 57371           ACADÉMICO              URBANO        TARDE
#
#        ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 235231                     N                 54.0             36.0
# 141079                     N                 64.0             50.0
# 112248                     N                 48.0             41.0
# 357148                     N                 65.0             24.0
# 200971                     N                 61.0             56.0
# 313401                     N                 43.0             34.0
# 11270                      N                 62.0             72.0
# 175187                     N                 68.0             62.0
# 370998                     N                 71.0             64.0
# 57371                      N                 63.0             47.0
#
#        PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL
# 235231             41.0                     41.0        38.0       213.0
# 141079             46.0                     62.0        50.0       275.0
# 112248             47.0                     43.0        36.0       220.0
# 357148             27.0                     66.0        53.0       230.0
# 200971             54.0                     53.0        51.0       278.0
# 313401             36.0                     37.0        35.0       187.0
# 11270              70.0                     73.0        83.0       352.0
# 175187             64.0                     60.0        61.0       317.0
# 370998             54.0                     58.0        52.0       305.0
# 57371              54.0                     48.0        58.0       267.0
#
# [10 rows x 40 columns]

# %%
# muestra registros de la columna 'ESTU_DEPTO_RESIDE'
df_acumulado_saber_11['ESTU_DEPTO_RESIDE'].value_counts()
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTÁ             61983
# ANTIOQUIA          52788
# VALLE              35988
# CUNDINAMARCA       27747
# ATLANTICO          23135
# SANTANDER          18638
# BOLIVAR            17874
# CORDOBA            14252
# NARIÑO             13128
# BOYACA             12463
# TOLIMA             12329
# MAGDALENA          11790
# NORTE SANTANDER    11392
# CAUCA              11113
# HUILA              10255
# CESAR               9572
# META                9463
# CALDAS              7839
# RISARALDA           7827
# SUCRE               7796
# LA GUAJIRA          6048
# BOGOTA              5403
# QUINDIO             4717
# CASANARE            4462
# CAQUETA             3346
# CHOCO               3295
# PUTUMAYO            2996
# ARAUCA              2462
# GUAVIARE             708
# AMAZONAS             586
# SAN ANDRES           425
# VICHADA              356
# VAUPES               246
# GUAINIA              204
# EXTRANJERO            96
# -                     16
# Name: count, dtype: int64

# %%
# La función columns, devuelve el nombre de las columnas del dataframe
df_acumulado_saber_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413002 entries, 0 to 413001
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ESTU_TIPODOCUMENTO            413002 non-null  object
#  1   ESTU_NACIONALIDAD             413002 non-null  object
#  2   ESTU_GENERO                   413002 non-null  object
#  3   ESTU_FECHANACIMIENTO          413000 non-null  object
#  4   PERIODO                       413002 non-null  int64
#  5   ESTU_CONSECUTIVO              413002 non-null  object
#  6   ESTU_PAIS_RESIDE              413002 non-null  object
#  7   ESTU_TIENEETNIA               413002 non-null  object
#  8   ESTU_DEPTO_RESIDE             412738 non-null  object
#  9   ESTU_MCPIO_RESIDE             412738 non-null  object
#  10  FAMI_ESTRATOVIVIENDA          412982 non-null  object
#  11  FAMI_PERSONASHOGAR            406893 non-null  object
#  12  FAMI_CUARTOSHOGAR             408289 non-null  object
#  13  FAMI_EDUCACIONPADRE           407015 non-null  object
#  14  FAMI_EDUCACIONMADRE           398146 non-null  object
#  15  FAMI_TRABAJOLABORPADRE        407141 non-null  object
#  16  FAMI_TRABAJOLABORMADRE        407544 non-null  object
#  17  FAMI_TIENEINTERNET            406992 non-null  object
#  18  FAMI_TIENECOMPUTADOR          407107 non-null  object
#  19  FAMI_TIENECONSOLAVIDEOJUEGOS  407375 non-null  object
#  20  FAMI_NUMLIBROS                406791 non-null  object
#  21  FAMI_SITUACIONECONOMICA       407050 non-null  object
#  22  ESTU_DEDICACIONLECTURADIARIA  412538 non-null  object
#  23  ESTU_DEDICACIONINTERNET       391404 non-null  object
#  24  ESTU_HORASSEMANATRABAJA       412723 non-null  object
#  25  ESTU_TIPOREMUNERACION         401748 non-null  object
#  26  COLE_NOMBRE_ESTABLECIMIENTO   413002 non-null  object
#  27  COLE_GENERO                   413002 non-null  object
#  28  COLE_NATURALEZA               413002 non-null  object
#  29  COLE_BILINGUE                 413002 non-null  object
#  30  COLE_CARACTER                 403048 non-null  object
#  31  COLE_AREA_UBICACION           413001 non-null  object
#  32  COLE_JORNADA                  413001 non-null  object
#  33  ESTU_PRIVADO_LIBERTAD         413001 non-null  object
#  34  PUNT_LECTURA_CRITICA          413001 non-null  float64
#  35  PUNT_MATEMATICAS              413001 non-null  float64
#  36  PUNT_C_NATURALES              413001 non-null  float64
#  37  PUNT_SOCIALES_CIUDADANAS      413001 non-null  float64
#  38  PUNT_INGLES                   412986 non-null  float64
#  39  PUNT_GLOBAL                   413001 non-null  float64
# dtypes: float64(6), int64(1), object(33)
# memory usage: 126.0+ MB

# %% [markdown]
# ## Análisis básico inicial del conjunto de datos

# %% [markdown]
# - Revisar la estructura del conjunto de datos para identificar columnas, tipos de datos y posibles problemas.
# - Identificar valores faltantes, valores atípicos y posibles inconsistencias en los datos.

# %%
# Obtener información general del conjunto de datos

df_acumulado_saber_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413002 entries, 0 to 413001
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   ESTU_TIPODOCUMENTO            413002 non-null  object
#  1   ESTU_NACIONALIDAD             413002 non-null  object
#  2   ESTU_GENERO                   413002 non-null  object
#  3   ESTU_FECHANACIMIENTO          413000 non-null  object
#  4   PERIODO                       413002 non-null  int64
#  5   ESTU_CONSECUTIVO              413002 non-null  object
#  6   ESTU_PAIS_RESIDE              413002 non-null  object
#  7   ESTU_TIENEETNIA               413002 non-null  object
#  8   ESTU_DEPTO_RESIDE             412738 non-null  object
#  9   ESTU_MCPIO_RESIDE             412738 non-null  object
#  10  FAMI_ESTRATOVIVIENDA          412982 non-null  object
#  11  FAMI_PERSONASHOGAR            406893 non-null  object
#  12  FAMI_CUARTOSHOGAR             408289 non-null  object
#  13  FAMI_EDUCACIONPADRE           407015 non-null  object
#  14  FAMI_EDUCACIONMADRE           398146 non-null  object
#  15  FAMI_TRABAJOLABORPADRE        407141 non-null  object
#  16  FAMI_TRABAJOLABORMADRE        407544 non-null  object
#  17  FAMI_TIENEINTERNET            406992 non-null  object
#  18  FAMI_TIENECOMPUTADOR          407107 non-null  object
#  19  FAMI_TIENECONSOLAVIDEOJUEGOS  407375 non-null  object
#  20  FAMI_NUMLIBROS                406791 non-null  object
#  21  FAMI_SITUACIONECONOMICA       407050 non-null  object
#  22  ESTU_DEDICACIONLECTURADIARIA  412538 non-null  object
#  23  ESTU_DEDICACIONINTERNET       391404 non-null  object
#  24  ESTU_HORASSEMANATRABAJA       412723 non-null  object
#  25  ESTU_TIPOREMUNERACION         401748 non-null  object
#  26  COLE_NOMBRE_ESTABLECIMIENTO   413002 non-null  object
#  27  COLE_GENERO                   413002 non-null  object
#  28  COLE_NATURALEZA               413002 non-null  object
#  29  COLE_BILINGUE                 413002 non-null  object
#  30  COLE_CARACTER                 403048 non-null  object
#  31  COLE_AREA_UBICACION           413001 non-null  object
#  32  COLE_JORNADA                  413001 non-null  object
#  33  ESTU_PRIVADO_LIBERTAD         413001 non-null  object
#  34  PUNT_LECTURA_CRITICA          413001 non-null  float64
#  35  PUNT_MATEMATICAS              413001 non-null  float64
#  36  PUNT_C_NATURALES              413001 non-null  float64
#  37  PUNT_SOCIALES_CIUDADANAS      413001 non-null  float64
#  38  PUNT_INGLES                   412986 non-null  float64
#  39  PUNT_GLOBAL                   413001 non-null  float64
# dtypes: float64(6), int64(1), object(33)
# memory usage: 126.0+ MB

# %%
# Descripción estadística de las variables numéricas
df_acumulado_saber_11.describe()
# Out:
#              PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# count  413002.000000         413001.000000     413001.000000
# mean    20193.376821             52.578197         51.105925
# std         2.777227             10.654102         12.191399
# min     20181.000000              0.000000          0.000000
# 25%     20194.000000             45.000000         42.000000
# 50%     20194.000000             53.000000         51.000000
# 75%     20194.000000             60.000000         60.000000
# max     20194.000000            100.000000        100.000000
#
#        PUNT_C_NATURALES  PUNT_SOCIALES_CIUDADANAS    PUNT_INGLES  \
# count     413001.000000             413001.000000  412986.000000
# mean          48.779918                 46.805080      49.142990
# std           11.019968                 12.395963      13.149954
# min            0.000000                  0.000000       0.000000
# 25%           41.000000                 37.000000      39.000000
# 50%           48.000000                 46.000000      48.000000
# 75%           56.000000                 56.000000      57.000000
# max          100.000000                100.000000     100.000000
#
#          PUNT_GLOBAL
# count  413001.000000
# mean      248.829059
# std        52.643476
# min         0.000000
# 25%       209.000000
# 50%       245.000000
# 75%       286.000000
# max       475.000000

# %%
# Descripción estadística de las variables numéricas sin notación científica

# Se configura la forma en que los números flotantes se muestran al imprimir un DataFrame en pandas.
# Se define función lambda que toma un número x y devuelve ese número formateado con 1 decimal.
pd.set_option('display.float_format', lambda x: '%.1f' % x)

df_acumulado_saber_11.describe()
# Out:
#        PERIODO  PUNT_LECTURA_CRITICA  PUNT_MATEMATICAS  PUNT_C_NATURALES  \
# count 413002.0              413001.0          413001.0          413001.0
# mean   20193.4                  52.6              51.1              48.8
# std        2.8                  10.7              12.2              11.0
# min    20181.0                   0.0               0.0               0.0
# 25%    20194.0                  45.0              42.0              41.0
# 50%    20194.0                  53.0              51.0              48.0
# 75%    20194.0                  60.0              60.0              56.0
# max    20194.0                 100.0             100.0             100.0
#
#        PUNT_SOCIALES_CIUDADANAS  PUNT_INGLES  PUNT_GLOBAL
# count                  413001.0     412986.0     413001.0
# mean                       46.8         49.1        248.8
# std                        12.4         13.1         52.6
# min                         0.0          0.0          0.0
# 25%                        37.0         39.0        209.0
# 50%                        46.0         48.0        245.0
# 75%                        56.0         57.0        286.0
# max                       100.0        100.0        475.0

# %% [markdown]
# - Periodo:
#     - La mayoría de los datos parecen concentrarse en el año 2019 y 2020, ya que los cuartiles y la media están más cerca de estos años.
#
# - Puntuaciones:
#     - Las puntuaciones mínimas para todas las asignaturas son 0, lo que indica que hay estudiantes que obtuvieron la puntuación más baja posible en estas materias.
#
#     - Las medias para todas las puntuaciones de las asignaturas están en un rango similar, alrededor de 45-52, lo que sugiere que los estudiantes, en promedio, tienen un rendimiento medio en estas asignaturas.
#
#     - Las desviaciones estándar son relativamente altas para todas las puntuaciones, lo que indica que hay una variabilidad significativa en las puntuaciones de los estudiantes.
#
#     - Las puntuaciones máximas para todas las materias son 100, lo que sugiere que hay estudiantes que obtuvieron la puntuación máxima posible.
#
#     - Las puntuaciones se encuentran en un rango de 0 a 500 para PUNT_GLOBAL, lo cual es un rango más amplio en comparación con las puntuaciones individuales de las asignaturas. Esto podría indicar que PUNT_GLOBAL es una combinación ponderada de las puntuaciones individuales o posiblemente incluye otros componentes no especificados en el conjunto de datos.
#
#     - Existen variabilidades significativas en las puntuaciones de los estudiantes, con algunos obteniendo puntuaciones muy bajas y otros muy altas. Esto podría indicar diferencias en la preparación, el esfuerzo o la capacidad de los estudiantes.
#
#     - Sería importante investigar más sobre la columna PUNT_GLOBAL para entender cómo se calcula y qué componentes incluye, ya que tiene un rango más amplio que las puntuaciones individuales de las materias.

# %%
# Descripción de las variables categóricas

df_acumulado_saber_11.describe(include=['object'])
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# count              413002            413002      413002
# unique                 10                39           3
# top                    TI          COLOMBIA           F
# freq               334668            411946      210390
#
#           ESTU_FECHANACIMIENTO  ESTU_CONSECUTIVO ESTU_PAIS_RESIDE  \
# count                   413000            413002           413002
# unique                   13668            413002               39
# top     01/01/1900 12:00:00 AM  SB11201810007354         COLOMBIA
# freq                      1327                 1           411946
#
#        ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# count           413002            412738            412738
# unique               3                36              1032
# top                 No            BOGOTÁ       BOGOTÁ D.C.
# freq            384418             61983             67386
#
#        FAMI_ESTRATOVIVIENDA  ... ESTU_HORASSEMANATRABAJA  \
# count                412982  ...                  412723
# unique                    8  ...                       6
# top               Estrato 2  ...                       0
# freq                 140626  ...                  267465
#
#        ESTU_TIPOREMUNERACION                     COLE_NOMBRE_ESTABLECIMIENTO  \
# count                 401748                                          413002
# unique                     5                                            9708
# top                       No  INSTITUCION EDUCATIVA FRANCISCO JOSE DE CALDAS
# freq                  283544                                             835
#
#        COLE_GENERO COLE_NATURALEZA COLE_BILINGUE COLE_CARACTER  \
# count       413002          413002        413002        403048
# unique           3               2             3             5
# top          MIXTO         OFICIAL             N     ACADÉMICO
# freq        399108          299700        339171        220117
#
#        COLE_AREA_UBICACION COLE_JORNADA ESTU_PRIVADO_LIBERTAD
# count               413001       413001                413001
# unique                   2            6                     2
# top                 URBANO       MAÑANA                     N
# freq                350294       191173                412896
#
# [4 rows x 33 columns]

# %%
# Identificar valores únicos por columna
print("\nValores únicos por columna:")
for column in df_acumulado_saber_11.columns:
    unique_values = df_acumulado_saber_11[column].unique()
    print(f"\n{column} ({len(unique_values)} valores únicos):\n{unique_values[:10]}")
    if len(unique_values) > 10:
        print("...")
# Out:
# Valores únicos por columna:
#
# ESTU_TIPODOCUMENTO (10 valores únicos):
# ['CC' 'TI' 'CR' 'CE' 'PE' 'PC' 'RC' 'PEP' 'NES' 'CCB']
#
# ESTU_NACIONALIDAD (39 valores únicos):
# ['COLOMBIA' 'ESTADOS UNIDOS' 'BRASIL' 'PANAMÁ' 'VENEZUELA' 'ECUADOR'
#  'NICARAGUA' 'ESPAÑA' 'ARGENTINA' 'MÉXICO']
# ...
#
# ESTU_GENERO (3 valores únicos):
# ['F' 'M' '-']
#
# ESTU_FECHANACIMIENTO (13669 valores únicos):
# ['29/09/1999' '19/03/2001' '31/07/2000' '20/01/2002' '23/10/2001'
#  '20/04/2001' '05/04/2000' '05/11/2001' '03/11/2000' '23/09/1999']
# ...
#
# PERIODO (2 valores únicos):
# [20181 20194]
#
# ESTU_CONSECUTIVO (413002 valores únicos):
# ['SB11201810007354' 'SB11201810018765' 'SB11201810028523'
#  'SB11201810003574' 'SB11201810024346' 'SB11201810006862'
#  'SB11201810017023' 'SB11201810048390' 'SB11201810010098'
#  'SB11201810012063']
# ...
#
# ESTU_PAIS_RESIDE (39 valores únicos):
# ['COLOMBIA' 'ESTADOS UNIDOS' 'BRASIL' 'PANAMÁ' 'VENEZUELA' 'ECUADOR'
#  'NICARAGUA' 'ESPAÑA' 'ARGENTINA' 'MÉXICO']
# ...
#
# ESTU_TIENEETNIA (3 valores únicos):
# ['No' 'Si' '-']
#
# ESTU_DEPTO_RESIDE (37 valores únicos):
# ['BOGOTA' 'VALLE' 'ATLANTICO' 'CUNDINAMARCA' 'ANTIOQUIA' 'RISARALDA'
#  'CAUCA' 'BOLIVAR' 'CAQUETA' 'NORTE SANTANDER']
# ...
#
# ESTU_MCPIO_RESIDE (1033 valores únicos):
# ['BOGOTÁ D.C.' 'CALI' 'YUMBO' 'SOLEDAD' 'CHÍA' 'ENVIGADO' 'PALMIRA'
#  'BARRANQUILLA' 'EL CERRITO' 'PEREIRA']
# ...
#
# FAMI_ESTRATOVIVIENDA (9 valores únicos):
# ['Estrato 6' 'Estrato 5' 'Estrato 1' 'Estrato 3' 'Estrato 2' 'Sin Estrato'
#  'Estrato 4' '-' nan]
#
# FAMI_PERSONASHOGAR (8 valores únicos):
# ['3 a 4' '1 a 2' '5 a 6' 'Sin Respuesta' '9 o más' '7 a 8' '-' nan]
#
# FAMI_CUARTOSHOGAR (9 valores únicos):
# ['Tres' 'Dos' 'Sin respuesta' 'Cinco' 'Seis o mas' 'Cuatro' 'Uno' nan '-']
#
# FAMI_EDUCACIONPADRE (15 valores únicos):
# ['Educación profesional completa' 'Postgrado'
#  'Secundaria (Bachillerato) completa' 'Técnica o tecnológica incompleta'
#  'Sin respuesta' 'Primaria incompleta'
#  'Secundaria (Bachillerato) incompleta' 'Técnica o tecnológica completa'
#  'Primaria completa' 'No sabe']
# ...
#
# FAMI_EDUCACIONMADRE (15 valores únicos):
# ['Educación profesional completa' 'Secundaria (Bachillerato) completa'
#  'Postgrado' 'Técnica o tecnológica incompleta' 'Sin respuesta'
#  'Primaria incompleta' 'Secundaria (Bachillerato) incompleta'
#  'Técnica o tecnológica completa' 'Primaria completa' 'No sabe']
# ...
#
# FAMI_TRABAJOLABORPADRE (16 valores únicos):
# ['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)'
#  'Trabaja por cuenta propia (por ejemplo plomero, electricista)'
#  'Trabaja en el hogar, no trabaja o estudia'
#  'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)'
#  'Es operario de máquinas o conduce vehículos (taxita, chofer)'
#  'Sin respuesta'
#  'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc'
#  'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial'
#  'No aplica' 'Pensionado']
# ...
#
# FAMI_TRABAJOLABORMADRE (16 valores únicos):
# ['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)'
#  'Trabaja en el hogar, no trabaja o estudia'
#  'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial'
#  'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)'
#  'Es vendedor o trabaja en atención al público' 'Sin respuesta'
#  'Es agricultor, pesquero o jornalero'
#  'Es operario de máquinas o conduce vehículos (taxita, chofer)'
#  'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc'
#  'Trabaja como personal de limpieza, mantenimiento, seguridad o construcción']
# ...
#
# FAMI_TIENEINTERNET (5 valores únicos):
# ['Si' 'No' 'Sin respuesta' '-' nan]
#
# FAMI_TIENECOMPUTADOR (4 valores únicos):
# ['Si' 'No' '-' nan]
#
# FAMI_TIENECONSOLAVIDEOJUEGOS (4 valores únicos):
# ['Si' 'No' '-' nan]
#
# FAMI_NUMLIBROS (6 valores únicos):
# ['MÁS DE 100 LIBROS' '26 A 100 LIBROS' '0 A 10 LIBROS' '11 A 25 LIBROS'
#  '-' nan]
#
# FAMI_SITUACIONECONOMICA (5 valores únicos):
# ['Igual' 'Mejor' 'Peor' '-' nan]
#
# ESTU_DEDICACIONLECTURADIARIA (7 valores únicos):
# ['Entre 1 y 2 horas' 'No leo por entretenimiento' '30 minutos o menos'
#  'Entre 30 y 60 minutos' '-' 'Más de 2 horas' nan]
#
# ESTU_DEDICACIONINTERNET (7 valores únicos):
# ['Entre 1 y 3 horas' 'Entre 30 y 60 minutos' 'Más de 3 horas'
#  '30 minutos o menos' '-' 'No Navega Internet' nan]
#
# ESTU_HORASSEMANATRABAJA (7 valores únicos):
# ['0' 'Entre 11 y 20 horas' '-' 'Menos de 10 horas' 'Más de 30 horas'
#  'Entre 21 y 30 horas' nan]
#
# ESTU_TIPOREMUNERACION (6 valores únicos):
# ['No' 'Si, en efectivo' '-' 'Si, en especie' 'Si, en efectivo y especie'
#  nan]
#
# COLE_NOMBRE_ESTABLECIMIENTO (9708 valores únicos):
# ['GIMN VERMONT' 'COLEGIO PHILADELPHIA INTERNACIONAL'
#  'INST TECNOLG EMPRESARIAL COLOMBIANO' 'SANTA  MARIA STELLA MARIS'
#  'COLEGIO DE SAN LUIS GONZAGA' 'COL COMFANDI - YUMBO' 'COL COLOMBO GALES'
#  'LICEO MIXTO PARA ADULTOS JOSE PRUDENCIO PADILLA'
#  'NUEVO GIMNASIO CRISTIANO' 'CENTRO EDUCATIVO DE ADULTOS CEAM']
# ...
#
# COLE_GENERO (3 valores únicos):
# ['MIXTO' 'FEMENINO' 'MASCULINO']
#
# COLE_NATURALEZA (2 valores únicos):
# ['NO OFICIAL' 'OFICIAL']
#
# COLE_BILINGUE (3 valores únicos):
# ['S' 'N' '-']
#
# COLE_CARACTER (6 valores únicos):
# ['ACADÉMICO' 'NO APLICA' 'TÉCNICO/ACADÉMICO' 'TÉCNICO' '-' nan]
#
# COLE_AREA_UBICACION (3 valores únicos):
# ['URBANO' 'RURAL' nan]
#
# COLE_JORNADA (7 valores únicos):
# ['COMPLETA' 'SABATINA' 'MAÑANA' 'NOCHE' 'TARDE' 'UNICA' nan]
#
# ESTU_PRIVADO_LIBERTAD (3 valores únicos):
# ['N' 'S' nan]
#
# PUNT_LECTURA_CRITICA (68 valores únicos):
# [71. 75. 42. 61. 69. 49. 35. 73. 43. 62.]
# ...
#
# PUNT_MATEMATICAS (75 valores únicos):
# [65. 77. 27. 62. 75. 61. 52. 49. 53. 46.]
# ...
#
# PUNT_C_NATURALES (67 valores únicos):
# [ 69. 100.  29.  72.  67.  50.  45.  61.  38.  65.]
# ...
#
# PUNT_SOCIALES_CIUDADANAS (73 valores únicos):
# [63. 81. 36. 70. 65. 55. 73. 41. 78. 37.]
# ...
#
# PUNT_INGLES (75 valores únicos):
# [90. 86. 29. 79. 71. 58. 76. 46. 83. 45.]
# ...
#
# PUNT_GLOBAL (386 valores únicos):
# [344. 417. 166. 336. 346. 270. 214. 338. 207. 226.]
# ...

# %%
#diagrama caja bidotes por columna
numeric_cols = df_acumulado_saber_11.select_dtypes(include=['float64', 'int64']).columns
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(3,3,i)
    sns.boxenplot(data=df_acumulado_saber_11, x=col)
    plt.title(col)

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Análisis de valores faltantes por columna
datos_faltantes = df_acumulado_saber_11.isnull().sum()
porcentaje_faltas = (df_acumulado_saber_11.isnull().sum() / len(df_acumulado_saber_11)) * 100

faltantes_df = pd.DataFrame({
    'Valores faltantes': datos_faltantes,
    'Porcentaje (%)' : porcentaje_faltas
})

# Ordernar de manera descendente por %
faltantes_df = faltantes_df.sort_values(by='Porcentaje (%)', ascending=False)
faltantes_df
# Out:
#                               Valores faltantes  Porcentaje (%)
# ESTU_DEDICACIONINTERNET                   21598             5.2
# FAMI_EDUCACIONMADRE                       14856             3.6
# ESTU_TIPOREMUNERACION                     11254             2.7
# COLE_CARACTER                              9954             2.4
# FAMI_NUMLIBROS                             6211             1.5
# FAMI_PERSONASHOGAR                         6109             1.5
# FAMI_TIENEINTERNET                         6010             1.5
# FAMI_EDUCACIONPADRE                        5987             1.4
# FAMI_SITUACIONECONOMICA                    5952             1.4
# FAMI_TIENECOMPUTADOR                       5895             1.4
# FAMI_TRABAJOLABORPADRE                     5861             1.4
# FAMI_TIENECONSOLAVIDEOJUEGOS               5627             1.4
# FAMI_TRABAJOLABORMADRE                     5458             1.3
# FAMI_CUARTOSHOGAR                          4713             1.1
# ESTU_DEDICACIONLECTURADIARIA                464             0.1
# ESTU_HORASSEMANATRABAJA                     279             0.1
# ESTU_MCPIO_RESIDE                           264             0.1
# ESTU_DEPTO_RESIDE                           264             0.1
# FAMI_ESTRATOVIVIENDA                         20             0.0
# PUNT_INGLES                                  16             0.0
# ESTU_FECHANACIMIENTO                          2             0.0
# COLE_JORNADA                                  1             0.0
# PUNT_C_NATURALES                              1             0.0
# ESTU_PRIVADO_LIBERTAD                         1             0.0
# PUNT_MATEMATICAS                              1             0.0
# PUNT_SOCIALES_CIUDADANAS                      1             0.0
# PUNT_LECTURA_CRITICA                          1             0.0
# COLE_AREA_UBICACION                           1             0.0
# PUNT_GLOBAL                                   1             0.0
# COLE_BILINGUE                                 0             0.0
# COLE_NATURALEZA                               0             0.0
# COLE_GENERO                                   0             0.0
# COLE_NOMBRE_ESTABLECIMIENTO                   0             0.0
# ESTU_NACIONALIDAD                             0             0.0
# ESTU_TIENEETNIA                               0             0.0
# ESTU_PAIS_RESIDE                              0             0.0
# ESTU_CONSECUTIVO                              0             0.0
# PERIODO                                       0             0.0
# ESTU_GENERO                                   0             0.0
# ESTU_TIPODOCUMENTO                            0             0.0

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# Identificar columnas con valores faltantes y decidir cómo manejarlos (eliminar, imputar, etc.).

# %% [markdown]
# ### Columna ESTU_TIPODOCUMENTO

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_TIPODOCUMENTO'
df_acumulado_saber_11['ESTU_TIPODOCUMENTO'].value_counts()
# Out:
# ESTU_TIPODOCUMENTO
# TI     334668
# CC      71769
# CR       4741
# CE        980
# NES       570
# PEP       161
# PE         97
# PC          9
# CCB         4
# RC          3
# Name: count, dtype: int64

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_TIPODOCUMENTO'
tipo_documento_counts = df_acumulado_saber_11['ESTU_TIPODOCUMENTO'].value_counts()

# Crear la gráfica de barras
plt.figure(figsize=(12, 4))
ax = tipo_documento_counts.plot(kind='bar', color = 'blue')

# Añadir la cantidad en cada barra
for i, v in enumerate(tipo_documento_counts):
    ax.text(i, v + 1000, str(v), ha = 'center', va='bottom', fontsize=10)

# Títulos y etiquetas
plt.title('Frecuencia de tipos de documento')
plt.xlabel('Tipo de documento')
plt.ylabel('Frecuencia')

# Mostrar la gráfica
plt.show()

# %% [markdown]
# ### Columna ESTU_NACIONALIDAD

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_NACIONALIDAD'
df_acumulado_saber_11['ESTU_NACIONALIDAD'].value_counts()
# Out:
# ESTU_NACIONALIDAD
# COLOMBIA                  411946
# VENEZUELA                    815
# ESTADOS UNIDOS                75
# ESPAÑA                        46
# ECUADOR                       26
# BRASIL                         9
# MÉXICO                         8
# CHILE                          8
# ARGENTINA                      7
# PERÚ                           7
# ALEMANIA                       6
# FRANCIA                        5
# COSTA RICA                     5
# ITALIA                         4
# CUBA                           4
# REPÚBLICA DOMINICANA           3
# EL SALVADOR                    3
# BOLIVIA                        2
# COMORAS                        2
# PANAMÁ                         2
# ARUBA                          1
# AFGANISTÁN                     1
# CHINA                          1
# COREA DEL NORTE                1
# PAÍSES BAJOS - HOLANDA         1
# DINAMARCA                      1
# REINO UNIDO                    1
# BÉLGICA                        1
# AUSTRIA                        1
# TAIWAN                         1
# ALBANIA                        1
# CROACIA                        1
# PORTUGAL                       1
# JAPÓN                          1
# SUIZA                          1
# CANADÁ                         1
# TERRITORIOS PALESTINOS         1
# NICARAGUA                      1
# CURAZAO                        1
# Name: count, dtype: int64

# %% [markdown]
# Se puede observar que hay registros con caracteres especiales (tildes) en el nombre. Reto a realizar:
# - Elimina (unicamente) las tiles de los registros

# %% [markdown]
# ### Columna ESTU_GENERO

# %%
# Obtener valores únicos y su frecuencia en la columna 'ESTU_NACIONALIDAD'
df_acumulado_saber_11['ESTU_GENERO'].value_counts()
# Out:
# ESTU_GENERO
# F    210390
# M    202528
# -        84
# Name: count, dtype: int64

# %% [markdown]
# - Los valores etiquetamos como "-", representan un 0.001% del total de registros, estos están representados con el caracter "-".
#
# - Se procederá a reemplazar en el DataFrame original ese caracter con la etiqueta de "No registrado".

# %%
# reemplazar valores "-"
df_acumulado_saber_11['ESTU_GENERO'] = df_acumulado_saber_11['ESTU_GENERO'].replace('-','No_informa')

# contar registros de la columna 'ESTU_GENERO'
df_acumulado_saber_11['ESTU_GENERO'].value_counts()
# Out:
# ESTU_GENERO
# F             210390
# M             202528
# No_informa        84
# Name: count, dtype: int64

# %%
# Cantidad de registros por el tipo de genero

# generar conteo de registros por valor único en la columna ESTU_GENERO
df_genero = df_acumulado_saber_11['ESTU_GENERO'].value_counts()

# establecer etiquetas y colores
etiquetas = ['F','M','No informa']
colores = ['#FFC0CB', '#6495ED', '#C0C0C0']

# crear gráfico de torta
plt.pie(df_genero, labels=etiquetas, colors=colores, autopct='%1.1f%%', startangle=90)

# agregar leyenda
plt.legend(title='Genero', loc = 'center left', bbox_to_anchor=(1.0, 0.5))

# mostrar gráfico
plt.show()

# %% [markdown]
# ### Columna ESTU_FECHANACIMIENTO

# %%
# contar registros de la columna 'ESTU_FECHANACIENTO'

df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].value_counts().sort_values(ascending=False)
# Out:
# ESTU_FECHANACIMIENTO
# 01/01/1900 12:00:00 AM    1327
# 09/20/2002 12:00:00 AM     634
# 09/09/2002 12:00:00 AM     620
# 09/24/2002 12:00:00 AM     619
# 09/17/2002 12:00:00 AM     618
#                           ...
# 03/09/1973 12:00:00 AM       1
# 10/04/1960 12:00:00 AM       1
# 08/17/1975 12:00:00 AM       1
# 04/16/1971 12:00:00 AM       1
# 12/21/1966 12:00:00 AM       1
# Name: count, Length: 13668, dtype: int64

# %% [markdown]
# En la columna 'ESTU_FECHANACIMIENTO' es evidente notar que hay un detalle muy especifico de la fecha de nacimiento de los estudiantes. Se puede ver que los valores están en formato de fecha y hora, para esta columna inicialmente transformaremos a tipo DATE ya que solo capturaremos el año de nacimiento.
#
# Anexo a eso, es evidente también la deformación en fechas de nacimiento, ejemplo:
#
# - 0002-04-20T00:00:00.000
# - 0004-05-20T00:00:00.000
# - 0002-06-20T00:00:00.000

# %% [markdown]
# Reto: ¿Qué opciones/acciones propones para dichas fechas?

# %%
# Es posible que lleguemos a evidenciar un error "OutOfBoundsDatetime: Out of bounds nanosecond timestamp" cuano ejecutemos el cambio de tipo de dato, indica que en la columna
# de fechas se encuentran valores que no se pueden representar correctamente como objetos de fecha y hora de pandas.

# Para solucionar ese error, debemos identificar los valores problemáticos y limpiarlos antes de convertir la columna al formato de fecha y hora de pandas.
# Una forma de hacerlo es mediante la función "to_datetime()" de pandas, pasando el argumento "errors='coerce'". De esta forma, cualquier valor que no pueda convertirse
# correctamente será reemplazado por "NaT" (valores faltantes en pandas).

# limpiar valores problemáticos
#df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].str.replace('\r', '')
#df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].str.replace('\n', '')

# convertir columna 'ESTU_FECHANACIMIENTO' al formato de fecha y hora de pandas
df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df_acumulado_saber_11['ESTU_FECHANACIMIENTO'], errors='coerce')

# obtener solo el año de nacimiento
df_acumulado_saber_11['ANIO_NACIMIENTO'] = df_acumulado_saber_11['ESTU_FECHANACIMIENTO'].dt.year

# Si deseamos, tenemos la opción de eliminar o no columnas innecesarias, en este caso la columna 'ESTU_FECHANACIMIENTO' será reemplazada por 'ANIO_NACIMIENTO'
df_acumulado_saber_11 = df_acumulado_saber_11.drop('ESTU_FECHANACIMIENTO', axis=1)

# mostrar resultados
df_acumulado_saber_11.head(3)
# Out:
# <ipython-input-24-2534831bbcfe>:13: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_acumulado_saber_11['ESTU_FECHANACIMIENTO'] = pd.to_datetime(df_acumulado_saber_11['ESTU_FECHANACIMIENTO'], errors='coerce')
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  PERIODO  ESTU_CONSECUTIVO  \
# 0                 CC          COLOMBIA           F    20181  SB11201810007354
# 1                 TI          COLOMBIA           M    20181  SB11201810018765
# 2                 TI          COLOMBIA           M    20181  SB11201810028523
#
#   ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# 0         COLOMBIA              No            BOGOTA       BOGOTÁ D.C.
# 1         COLOMBIA              No             VALLE              CALI
# 2         COLOMBIA              No             VALLE              CALI
#
#   FAMI_ESTRATOVIVIENDA  ... COLE_AREA_UBICACION COLE_JORNADA  \
# 0            Estrato 6  ...              URBANO     COMPLETA
# 1            Estrato 5  ...              URBANO     COMPLETA
# 2            Estrato 1  ...               RURAL     SABATINA
#
#   ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA PUNT_MATEMATICAS  \
# 0                     N                 71.0             65.0
# 1                     N                 75.0             77.0
# 2                     N                 42.0             27.0
#
#   PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES PUNT_GLOBAL  \
# 0             69.0                     63.0        90.0       344.0
# 1            100.0                     81.0        86.0       417.0
# 2             29.0                     36.0        29.0       166.0
#
#   ANIO_NACIMIENTO
# 0          1999.0
# 1          2001.0
# 2          2000.0
#
# [3 rows x 40 columns]

# %%
df_acumulado_saber_11['ANIO_NACIMIENTO'].value_counts().sort_values(ascending=False)
# Out:
# ANIO_NACIMIENTO
# 2000.0    6865
# 2001.0    5639
# 1999.0    3448
# 1998.0     914
# 2002.0     864
#           ...
# 1955.0       2
# 1942.0       1
# 1949.0       1
# 1944.0       1
# 1953.0       1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# Podemos observar algunos registros que son Outliers (valores atipicos):
#
# La edad promedio de presentación del examen ICFES es entre los 14 y 20 años, por ende los nacidos entre los años 2009 y 2020, o son datos erroneos o mal diligenciados.
#
# Sin embargo, hay una excepción, ocurrio en el año 2012. Uno de los registros de estudiantes con menor edad en presentar el examen ICFES pertenece a [Juan Sebastián Andrés Pérez Riaño](https://www.elcolombiano.com/colombia/nino-de-doce-anos-presento-el-icfes-y-se-va-a-graduar-GE18585650), un niño de 12 años que estudio en Yopal, Casanare. Esto fue en 2022, con base a este, y generando una hipótesis (que luego deberá ser validada o descartada), se limpiaran datos de los nacidos de 2008 hacía adelante, es decir, los nacidos entre 2009 y 2020, serán registros a eliminar.

# %%
# contar registros de la columna 'ANIO_NACIMIENTO'
conteo_por_anio = df_acumulado_saber_11['ANIO_NACIMIENTO'].value_counts()

# filtrar años de interés, entre 2009 y 2020
filtro = (conteo_por_anio.index >= 2009) & (conteo_por_anio.index <= 2020)
conteo_por_anio_filtrado = conteo_por_anio.loc[filtro]

# Mostrar resultados
print(conteo_por_anio_filtrado)
plt.show()

print("Entre los años 2009 y 2020, hay un total de:", conteo_por_anio_filtrado.sum())
# Out:
# ANIO_NACIMIENTO
# 2017.0    21
# 2009.0     7
# 2011.0     4
# 2010.0     4
# 2012.0     2
# Name: count, dtype: int64
# Entre los años 2009 y 2020, hay un total de: 38

# %%
# Identificar los índices de los registros a eliminar
indices_eliminar = df_acumulado_saber_11[(df_acumulado_saber_11['ANIO_NACIMIENTO']
                                          >= 2009) & (df_acumulado_saber_11['ANIO_NACIMIENTO']<=2009)].index

# Eliminar los registros
df_resultados = df_acumulado_saber_11.drop(indices_eliminar)

print("Se eliminaron",conteo_por_anio_filtrado.sum(),'resgistros que pertenecen a los nacidos entre 2009 y 2020')
# Out:
# Se eliminaron 38 resgistros que pertenecen a los nacidos entre 2009 y 2020

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df_acumulado_saber_11['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 393206

# %%
# Calcular el número de registros con valores vacíos en ANIO_NACIMIENTO por grupo
vacios_por_grupo = df_acumulado_saber_11.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.isna().sum())

# Ordenar de mayor a menor
vacios_grupo_sorted = vacios_por_grupo.sort_values(ascending=False)

# Imprimir cantidad de valores vacíos ordenados de mayor a menor
for grupo in vacios_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores vacíos: {vacios_grupo_sorted.loc[grupo]}")
    print('-------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores vacíos: 320409
# -------------------------------
# Grupo: CC
# Cantidad de valores vacíos: 66757
# -------------------------------
# Grupo: CR
# Cantidad de valores vacíos: 4379
# -------------------------------
# Grupo: CE
# Cantidad de valores vacíos: 855
# -------------------------------
# Grupo: NES
# Cantidad de valores vacíos: 570
# -------------------------------
# Grupo: PEP
# Cantidad de valores vacíos: 161
# -------------------------------
# Grupo: PE
# Cantidad de valores vacíos: 65
# -------------------------------
# Grupo: CCB
# Cantidad de valores vacíos: 4
# -------------------------------
# Grupo: PC
# Cantidad de valores vacíos: 4
# -------------------------------
# Grupo: RC
# Cantidad de valores vacíos: 2
# -------------------------------

# %%
# Calcular el número total de valores no nulos en ANIO_NACIMIENTO
total_no_nulos = df_acumulado_saber_11['ANIO_NACIMIENTO'].notna().sum()

# Calcular el número de registros con valores no nulos en ANIO_NACIMIENTO por grupo
no_nulos_por_grupo = df_acumulado_saber_11.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.notna().sum())

# Calcular el porcentaje de cada grupo respecto al total de valores no nulos
porcentaje_por_grupo = (no_nulos_por_grupo / total_no_nulos) * 100

# Ordenar de mayor a menor
porcentaje_por_grupo_sorted = porcentaje_por_grupo.sort_values(ascending=False)

# Imprimir porcentaje de valores no nulos y cantidad por grupo
for grupo in porcentaje_por_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores no nulos: {no_nulos_por_grupo.loc[grupo]}")
    print(f"Porcentajes sobre el total de valores no nulos: {porcentaje_por_grupo_sorted.loc[grupo]:.2f}%")
    print('-------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores no nulos: 14259
# Porcentajes sobre el total de valores no nulos: 72.03%
# -------------------------------
# Grupo: CC
# Cantidad de valores no nulos: 5012
# Porcentajes sobre el total de valores no nulos: 25.32%
# -------------------------------
# Grupo: CR
# Cantidad de valores no nulos: 362
# Porcentajes sobre el total de valores no nulos: 1.83%
# -------------------------------
# Grupo: CE
# Cantidad de valores no nulos: 125
# Porcentajes sobre el total de valores no nulos: 0.63%
# -------------------------------
# Grupo: PE
# Cantidad de valores no nulos: 32
# Porcentajes sobre el total de valores no nulos: 0.16%
# -------------------------------
# Grupo: PC
# Cantidad de valores no nulos: 5
# Porcentajes sobre el total de valores no nulos: 0.03%
# -------------------------------
# Grupo: RC
# Cantidad de valores no nulos: 1
# Porcentajes sobre el total de valores no nulos: 0.01%
# -------------------------------
# Grupo: CCB
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: NES
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: PEP
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------

# %% [markdown]
# Es fundamental distribuir adecuadamente los valores nulos o vacíos en la columna 'ANIO_NACIMIENTO' según el tipo de documento 'ESTU_TIPODOCUMENTO'. Podemos basarnos en la distribución de porcentajes de los valores no nulos como muestra. Por ejemplo, el tipo de documento 'TI' representa el 72.03% de los registros no nulos, mientras que 'CC' representa el 25.32%.
#
# Esto implica que de los 871,802 registros con tipo de documento 'TI', deberíamos asignarlos en los años 2003, 2004, 2005, 2006, 2007 y 2008. La asignación debería distribuirse de la siguiente manera:
#
# El 50% de los registros se asignarán a los años 2003 y 2004.
# El 30% de los registros se asignarán al año 2005.
# El 20% restante se distribuirá entre los años 2006, 2007 y 2008. Esta distribución proporciona una manera equitativa y representativa de llenar los valores nulos basándose en la proporción de los registros no nulos para cada tipo de documento.

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'TI' y ANIO_NACIMIENTO es NaN
filtro_ti = (df_acumulado_saber_11['ESTU_TIPODOCUMENTO'] == 'TI') & (df_acumulado_saber_11['ANIO_NACIMIENTO'].isna())

# Número de registros a asignar
num_registro_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
                2003: 0.5,
                2004: 0.5,
                2005: 0.3,
                2006: 0.2,
                2007: 0.2,
                2008: 0.2,
                }

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidad_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items() }

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidad_ajustadas.keys()), size=num_registro_ti, p=list(probabilidad_ajustadas.values()))

# Asignar los años a los registros filtrados
df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print(df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# ANIO_NACIMIENTO
# 2004.0    84038
# 2003.0    83918
# 2005.0    50762
# 2006.0    34026
# 2007.0    33885
# 2008.0    33780
# Name: count, dtype: int64

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'CC' y ANIO_NACIMIENTO es NaN
filtro_ti = (df_acumulado_saber_11['ESTU_TIPODOCUMENTO'] == 'CC') & (df_acumulado_saber_11['ANIO_NACIMIENTO'].isna())

# Número de registros a asignar
num_registro_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
                2002: 0.5,
                2001: 0.5,
                2000: 0.3,
                1999: 0.1,
                1998: 0.1,
                1997: 0.1,
                1996: 0.1,
                1995: 0.1,
                1994: 0.1
                }

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidad_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items() }

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidad_ajustadas.keys()), size=num_registro_ti, p=list(probabilidad_ajustadas.values()))

# Asignar los años a los registros filtrados
df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print("Distribución de años asignados a CC")
print(df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# Distribución de años asignados a CC
# ANIO_NACIMIENTO
# 2002.0    17621
# 2001.0    17559
# 2000.0    10524
# 1995.0     3559
# 1994.0     3541
# 1998.0     3535
# 1996.0     3528
# 1999.0     3451
# 1997.0     3439
# Name: count, dtype: int64

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df_acumulado_saber_11['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 6040

# %%
# Calcular el número total de valores no nulos en ANIO_NACIMIENTO
total_no_nulos = df_acumulado_saber_11['ANIO_NACIMIENTO'].notna().sum()

# Calcular el número de registros con valores no nulos en ANIO_NACIMIENTO por grupo
no_nulos_por_grupo = df_acumulado_saber_11.groupby('ESTU_TIPODOCUMENTO')['ANIO_NACIMIENTO'].apply(lambda x: x.notna().sum())

# Calcular el porcentaje de cada grupo respecto al total de valores no nulos
porcentaje_por_grupo = (no_nulos_por_grupo / total_no_nulos) * 100

# Ordenar de mayor a menor
porcentaje_por_grupo_sorted = porcentaje_por_grupo.sort_values(ascending=False)

# Imprimir porcentaje de valores no nulos y cantidad por grupo
for grupo in porcentaje_por_grupo_sorted.index:
    print(f"Grupo: {grupo}")
    print(f"Cantidad de valores no nulos: {no_nulos_por_grupo.loc[grupo]}")
    print(f"Porcentajes sobre el total de valores no nulos: {porcentaje_por_grupo_sorted.loc[grupo]:.2f}%")
    print('-------------------------------')
# Out:
# Grupo: TI
# Cantidad de valores no nulos: 334668
# Porcentajes sobre el total de valores no nulos: 82.24%
# -------------------------------
# Grupo: CC
# Cantidad de valores no nulos: 71769
# Porcentajes sobre el total de valores no nulos: 17.64%
# -------------------------------
# Grupo: CR
# Cantidad de valores no nulos: 362
# Porcentajes sobre el total de valores no nulos: 0.09%
# -------------------------------
# Grupo: CE
# Cantidad de valores no nulos: 125
# Porcentajes sobre el total de valores no nulos: 0.03%
# -------------------------------
# Grupo: PE
# Cantidad de valores no nulos: 32
# Porcentajes sobre el total de valores no nulos: 0.01%
# -------------------------------
# Grupo: PC
# Cantidad de valores no nulos: 5
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: RC
# Cantidad de valores no nulos: 1
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: CCB
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: NES
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------
# Grupo: PEP
# Cantidad de valores no nulos: 0
# Porcentajes sobre el total de valores no nulos: 0.00%
# -------------------------------

# %% [markdown]
# Considerando que existen 16,697 registros sin una asignación de 'ANIO_NACIMIENTO' y teniendo en cuenta el comportamiento de los grupos por año:
#
# 1. Grupo TI:
#     - Cantidad: 886,061
#     - Porcentaje: 82.84%
#
# 2. Grupo CC:
#     - Cantidad: 183,034
#     - Porcentaje: 17.11%
#
# Se procede a asignar de manera aleatoria el 82.84% de los registros hacia las edades de menores de edad, distribuidas de la siguiente manera:
#
# Años y porcentajes para menores de edad:
#
# - 2003: 0.5
# - 2004: 0.5
# - 2005: 0.3
# - 2006: 0.2
#
# Para los mayores de edad, se asignará de manera aleatoria el 17.11% de los registros, distribuidos así: Años y porcentajes para mayores de edad:
#
# - 2002: 0.5
# - 2001: 0.5
# - 2000: 0.3
# - 1999: 0.1
# - 1998: 0.1
# - 1997: 0.1
# - 1996: 0.1

# %%
# Filtro para registros donde ESTU_TIPODOCUMENTO es igual a 'CC' y ANIO_NACIMIENTO es NaN
tipos_documento = ['V', 'PEP', 'NUIP', 'NIP', 'NES', 'CCB', 'RC', 'PC', 'PE', 'CE', 'CR']
filtro_ti = df_acumulado_saber_11['ESTU_TIPODOCUMENTO'].isin(tipos_documento)& df_acumulado_saber_11['ANIO_NACIMIENTO'].isna()

# Número de registros a asignar
num_registro_ti = filtro_ti.sum()

# Distribución de asignación ajustada
distribucion = {
                2006: 0.20,
                2005: 0.20,
                2004: 0.20,
                2003: 0.20,
                2002: 0.2,
                2001: 0.2,
                2000: 0.2,
                1999: 0.1,
                1998: 0.1,
                1997: 0.1,
                1996: 0.1,
                1995: 0.1,
                1994: 0.1,
                }

# Ajustar las probabilidades para que sumen 1
total_probabilidad = sum(distribucion.values())
probabilidad_ajustadas = {key: value / total_probabilidad for key, value in distribucion.items() }

# Generar una lista de años basada en la distribución ajustada
anos_distribucion = np.random.choice(list(probabilidad_ajustadas.keys()), size=num_registro_ti, p=list(probabilidad_ajustadas.values()))

# Asignar los años a los registros filtrados
df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'] = anos_distribucion

# Verificar los cambios
print("Distribución de años asignados a CC")
print(df_acumulado_saber_11.loc[filtro_ti, 'ANIO_NACIMIENTO'].value_counts())
# Out:
# Distribución de años asignados a CC
# ANIO_NACIMIENTO
# 2006.0    626
# 2005.0    615
# 2000.0    601
# 2004.0    600
# 2003.0    598
# 2001.0    594
# 2002.0    574
# 1994.0    332
# 1998.0    321
# 1996.0    313
# 1997.0    309
# 1999.0    282
# 1995.0    275
# Name: count, dtype: int64

# %%
# Conteo de registros con NaN, null o vacíos en la columna 'ANIO_NACIMIENTO'
df_acumulado_saber_11['ANIO_NACIMIENTO'].isna().sum()
# Out:
# 0

# %% [markdown]
# Podemos ver que no hay valores en cero en la columna 'ANIO_NACIMIENTO' con respecto a los valores NaN presentes.

# %%
df_acumulado_saber_11.sample(5)
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  PERIODO  \
# 175762                 TI          COLOMBIA           F    20194
# 298218                 TI          COLOMBIA           F    20194
# 14935                  CC          COLOMBIA           M    20181
# 25601                  TI          COLOMBIA           F    20194
# 276811                 TI          COLOMBIA           M    20194
#
#         ESTU_CONSECUTIVO ESTU_PAIS_RESIDE ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  \
# 175762  SB11201940426474         COLOMBIA              No            BOYACA
# 298218  SB11201940357026         COLOMBIA              No             VALLE
# 14935   SB11201810012786         COLOMBIA              No            BOGOTA
# 25601   SB11201940345034         COLOMBIA              No           CORDOBA
# 276811  SB11201940518699         COLOMBIA              No            CALDAS
#
#        ESTU_MCPIO_RESIDE FAMI_ESTRATOVIVIENDA  ... COLE_AREA_UBICACION  \
# 175762     PUERTO BOYACÁ            Estrato 1  ...              URBANO
# 298218              CALI            Estrato 2  ...              URBANO
# 14935        BOGOTÁ D.C.            Estrato 3  ...              URBANO
# 25601             CERETÉ            Estrato 1  ...              URBANO
# 276811         RISARALDA            Estrato 2  ...              URBANO
#
#        COLE_JORNADA ESTU_PRIVADO_LIBERTAD PUNT_LECTURA_CRITICA  \
# 175762       MAÑANA                     N                 49.0
# 298218       MAÑANA                     N                 61.0
# 14935         NOCHE                     N                 58.0
# 25601        MAÑANA                     N                 33.0
# 276811       MAÑANA                     N                 54.0
#
#        PUNT_MATEMATICAS PUNT_C_NATURALES PUNT_SOCIALES_CIUDADANAS PUNT_INGLES  \
# 175762             60.0             52.0                     49.0        56.0
# 298218             61.0             62.0                     51.0        68.0
# 14935              63.0             67.0                     62.0        51.0
# 25601              43.0             35.0                     34.0        39.0
# 276811             65.0             58.0                     52.0        70.0
#
#        PUNT_GLOBAL ANIO_NACIMIENTO
# 175762       264.0          2003.0
# 298218       297.0          2003.0
# 14935        308.0          1999.0
# 25601        182.0          2006.0
# 276811       291.0          2003.0
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Columna ESTU_TIENEETNIA

# %%
# generar conteo de registros por valor único en la columna ESTU_TIENEETNIA que hace referencia si pertenece o no a un tipo de etnia.

df_tenia = df_acumulado_saber_11['ESTU_TIENEETNIA'].value_counts().reset_index()
df_tenia.columns = ['Etenia', 'Cantidad']
df_tenia
# Out:
#   Etenia  Cantidad
# 0     No    384418
# 1     Si     28303
# 2      -       281

# %%
# generar conteo de registros por valor único en la columna ESTU_TIENEETNIA que hace referencia si pertenece o no a un tipo de etnia.
df_tenia = df_acumulado_saber_11['ESTU_TIENEETNIA'].value_counts().reset_index()
df_tenia.columns = ['Etnia', 'Cantidad']

# configurar etiquetas
labels = df_tenia['Etnia']
sizes = df_tenia['Cantidad']
explode = (0, 0.1, 0)

 # separar una porción del gráfico

# configurar la figura y el eje
fig, ax = plt.subplots()
fig.set_size_inches(15, 5)

# crear gráfico de dona
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90, textprops={'fontsize': 14}, wedgeprops={'width': 0.6})

# agregar etiqueta central
ax.text(0, 0, 'Etnia', horizontalalignment='center', verticalalignment='center', fontsize=10, fontweight='bold')

# mostrar resultados
plt.show()

# %%
# Los valores que estan etiquetados como "el signo menos", representan un 0.06% del total de registros, estos estan representados con el caracter "-".
# Se procederá a reemplazar en el DataFrame original ese caracter con la etiqueta de "Desconocido".

# reemplazar valores "-"
df_acumulado_saber_11['ESTU_TIENEETNIA'] = df_acumulado_saber_11['ESTU_TIENEETNIA'].replace('-','No responde')

# contar registros de la columna 'ESTU_GENERO'
df_acumulado_saber_11['ESTU_TIENEETNIA'].value_counts()
# Out:
# ESTU_TIENEETNIA
# No             384418
# Si              28303
# No responde       281
# Name: count, dtype: int64

# %% [markdown]
# ### Columna ESTU_DEPTO_RESIDE

# %%
# generar conteo de registros por valor único en la columna ESTU_DEPTO_RESIDE que hace referencia al departamento de residencia

df_acumulado_saber_11['ESTU_DEPTO_RESIDE'].value_counts()
# Out:
# ESTU_DEPTO_RESIDE
# BOGOTÁ             61983
# ANTIOQUIA          52788
# VALLE              35988
# CUNDINAMARCA       27747
# ATLANTICO          23135
# SANTANDER          18638
# BOLIVAR            17874
# CORDOBA            14252
# NARIÑO             13128
# BOYACA             12463
# TOLIMA             12329
# MAGDALENA          11790
# NORTE SANTANDER    11392
# CAUCA              11113
# HUILA              10255
# CESAR               9572
# META                9463
# CALDAS              7839
# RISARALDA           7827
# SUCRE               7796
# LA GUAJIRA          6048
# BOGOTA              5403
# QUINDIO             4717
# CASANARE            4462
# CAQUETA             3346
# CHOCO               3295
# PUTUMAYO            2996
# ARAUCA              2462
# GUAVIARE             708
# AMAZONAS             586
# SAN ANDRES           425
# VICHADA              356
# VAUPES               246
# GUAINIA              204
# EXTRANJERO            96
# -                     16
# Name: count, dtype: int64

# %% [markdown]
# **Reto: De la columna ESTU_DEPTO_RESIDE organizar Bogotá a un unico registro**

# %% [markdown]
# ### Columna ESTU_MCPIO_RESIDE

# %%
# Generar conteo de registros por valor único en la columna ESTU_MCPIO_RESIDE que hace referencia al municipio de residencia

unique_values = df_acumulado_saber_11['ESTU_MCPIO_RESIDE'].unique().tolist()
unique_values
# Out:
# ['BOGOTÁ D.C.',
#  'CALI',
#  'YUMBO',
#  'SOLEDAD',
#  'CHÍA',
#  'ENVIGADO',
#  'PALMIRA',
#  'BARRANQUILLA',
#  'EL CERRITO',
#  'PEREIRA',
#  'POPAYÁN',
#  'GUACARÍ',
#  'MEDELLÍN',
#  'GUADALAJARA DE BUGA',
#  'CARTAGENA DE INDIAS',
#  'EL PAUJÍL',
#  'LOS PATIOS',
#  'MONTERÍA',
#  'LA PLATA',
#  'PASTO',
#  'SOACHA',
#  'BELÉN DE UMBRÍA',
#  'ILES',
#  'MUTATÁ',
#  'ANCUYÁ',
#  'DUITAMA',
#  'PACHO',
#  'CAJICÁ',
#  'GUADALUPE',
#  'ARAUCA',
#  'VICTORIA',
#  'JAMUNDÍ',
#  'ZIPAQUIRÁ',
#  'MANIZALES',
#  'SAN DIEGO',
#  'FLORIDABLANCA',
#  'RESTREPO',
#  '-',
#  'DAGUA',
#  'INÍRIDA',
#  'BUCARAMANGA',
#  'PAMPLONA',
#  'PUERTO TEJADA',
#  'IBAGUÉ',
#  'CARTAGO',
#  'CANDELARIA',
#  'CAICEDONIA',
#  'APARTADÓ',
#  'VALLEDUPAR',
#  'PIEDECUESTA',
#  'TENJO',
#  'SANTA MARTA',
#  'SAN SEBASTIÁN DE MARIQUITA',
#  'MOCOA',
#  'EL CARMEN DE VIBORAL',
#  'GIRÓN',
#  'FUSAGASUGÁ',
#  'FLORIDA',
#  'FUNZA',
#  'PITALITO',
#  'CAMPO DE LA CRUZ',
#  'ARMENIA',
#  'VIJES',
#  'MAGANGUÉ',
#  'MÁLAGA',
#  'LA MESA',
#  'BELLO',
#  'LA CEJA',
#  'NEIVA',
#  'SANDONÁ',
#  'VILLAVICENCIO',
#  'TAME',
#  'LA CUMBRE',
#  'MAICAO',
#  'AGUACHICA',
#  'SANTANDER DE QUILICHAO',
#  'POTOSÍ',
#  'VILLA RICA',
#  'COTA',
#  'PUPIALES',
#  'ROLDANILLO',
#  'MALAMBO',
#  'SAN ANDRÉS',
#  'VISTAHERMOSA',
#  'SABANETA',
#  'SANTA ROSA DE CABAL',
#  'VILLA DEL ROSARIO',
#  'FACATATIVÁ',
#  'TABIO',
#  'MOSQUERA',
#  'MONTELÍBANO',
#  'FLORENCIA',
#  'ACACÍAS',
#  'GIRARDOTA',
#  'EL ZULIA',
#  'MADRID',
#  'VILLAMARÍA',
#  'PAZ DE ARIPORO',
#  'SAN GIL',
#  'TUNJA',
#  'MONTENEGRO',
#  'ALBANIA',
#  'YOPAL',
#  'BUESACO',
#  'MACHETÁ',
#  'GIRARDOT',
#  'SAN JOSÉ DEL GUAVIARE',
#  'CÚCUTA',
#  'GUAPOTÁ',
#  'CIÉNAGA',
#  'PATÍA',
#  'LA UNIÓN',
#  'LA DORADA',
#  'LA ESTRELLA',
#  'ITAGÜÍ',
#  'CABRERA',
#  'BUENAVENTURA',
#  'DOSQUEBRADAS',
#  'PAILITAS',
#  'PUERTO WILCHES',
#  'TOTORÓ',
#  'IPIALES',
#  'CHIQUINQUIRÁ',
#  'TULUÁ',
#  'MANZANARES',
#  'LOURDES',
#  'CALDAS',
#  'VITERBO',
#  'PUERRES',
#  'SOGAMOSO',
#  'SOCOTÁ',
#  'ZAPATOCA',
#  'GUACHENÉ',
#  'CUBARRAL',
#  'MACEO',
#  'PUERTO ASÍS',
#  'BOAVITA',
#  'CHINCHINÁ',
#  'MUTISCUA',
#  'CHOCONTÁ',
#  'CIRCASIA',
#  'LEJANÍAS',
#  'PIENDAMÓ - TUNÍA',
#  'ZARZAL',
#  'SARAVENA',
#  'EL SANTUARIO',
#  'ORITO',
#  'SANTA BÁRBARA',
#  'BOJACÁ',
#  'EBÉJICO',
#  'BETULIA',
#  'TAURAMENA',
#  'QUIBDÓ',
#  'PUERTO COLOMBIA',
#  'GRANADA',
#  'EL ROSAL',
#  'TIERRALTA',
#  'PALOCABILDO',
#  'RIOSUCIO',
#  'COCORNÁ',
#  'PRADERA',
#  'COGUA',
#  'CERRO DE SAN ANTONIO',
#  'LA FLORIDA',
#  'PUERTO LÓPEZ',
#  'PLANADAS',
#  'MARÍA LA BAJA',
#  'SOPÓ',
#  'CUMBAL',
#  'PALMAS DEL SOCORRO',
#  'EL COLEGIO',
#  'FREDONIA',
#  'LA CALERA',
#  'OCAÑA',
#  'SAMANÁ',
#  'IMUÉS',
#  'SAN PELAYO',
#  'DONMATÍAS',
#  'GUAMO',
#  'GUADUAS',
#  'SAN LUIS',
#  'SOCORRO',
#  'CALIMA',
#  'BARBOSA',
#  'RETIRO',
#  'SIBATÉ',
#  'ANDALUCÍA',
#  'YOTOCO',
#  'AGUAZUL',
#  'ARMERO',
#  'GINEBRA',
#  'BUGALAGRANDE',
#  'TOCANCIPÁ',
#  'SAN BERNARDO',
#  'CABUYARO',
#  'CHALÁN',
#  'EXTRANJERO',
#  'LA VICTORIA',
#  'GUARNE',
#  'MARINILLA',
#  'NARIÑO',
#  'SAN VICENTE FERRER',
#  'SUESCA',
#  'JUAN DE ACOSTA',
#  'FONSECA',
#  'PONEDERA',
#  'ANAPOIMA',
#  'SUAZA',
#  'RIONEGRO',
#  'SABANAS DE SAN ÁNGEL',
#  'ALTAMIRA',
#  'ITUANGO',
#  'HATONUEVO',
#  'SINCELEJO',
#  'ACEVEDO',
#  'VILLANUEVA',
#  'VILLA DE SAN DIEGO DE UBATÉ',
#  'SUSACÓN',
#  'ALMAGUER',
#  'BOYACÁ',
#  'SAN FRANCISCO',
#  'BOLÍVAR',
#  'COPACABANA',
#  'ALDANA',
#  'BALBOA',
#  'SANTA ROSA DE OSOS',
#  'TANGUA',
#  'COYAIMA',
#  'REMEDIOS',
#  'PORE',
#  'GUACHETÁ',
#  'MURINDÓ',
#  'ARBELÁEZ',
#  'SAN PEDRO DE LOS MILAGROS',
#  'CAJIBÍO',
#  'VERSALLES',
#  'GUACHUCAL',
#  'SAN PEDRO',
#  'TOLEDO',
#  'SUBACHOQUE',
#  'RICAURTE',
#  'CONCORDIA',
#  'LEBRIJA',
#  'TRINIDAD',
#  'RIVERA',
#  'FILANDIA',
#  'MESETAS',
#  'PUEBLO RICO',
#  'ANSERMA',
#  'FALAN',
#  'YARUMAL',
#  'GARZÓN',
#  'SANTO DOMINGO',
#  'COLOMBIA',
#  'LA VIRGINIA',
#  'OLAYA HERRERA',
#  'EL CASTILLO',
#  'CALARCÁ',
#  'SANTA ANA',
#  'MONTECRISTO',
#  'EL PASO',
#  'GALAPA',
#  'BARANOA',
#  'CORINTO',
#  'VALENCIA',
#  'LORICA',
#  'SABANALARGA',
#  'ARJONA',
#  'PUERTO GAITÁN',
#  'SAN ONOFRE',
#  'EL CARMEN DE BOLÍVAR',
#  'TOLÚ VIEJO',
#  'RIOFRÍO',
#  'SAMPUÉS',
#  'LA APARTADA',
#  'CIÉNAGA DE ORO',
#  'BARRANCAS',
#  'SAHAGÚN',
#  'NOCAIMA',
#  'BARRANCABERMEJA',
#  'TURBACO',
#  'CERETÉ',
#  'GUAPÍ',
#  'SAN MARCOS',
#  'MIRANDA',
#  'EL RETÉN',
#  'AGUSTÍN CODAZZI',
#  'HATILLO DE LOBA',
#  'ARIGUANÍ',
#  'SAN SEBASTIÁN DE BUENAVISTA',
#  'PUEBLO NUEVO',
#  'RIOHACHA',
#  'SAN ANTERO',
#  'AYAPEL',
#  'ACHÍ',
#  'PELAYA',
#  'SAN JUAN DE URABÁ',
#  'CURUMANÍ',
#  'SUAITA',
#  'URIBIA',
#  'BOSCONIA',
#  'PLANETA RICA',
#  'CALDONO',
#  'FUNDACIÓN',
#  'PUERTO LIBERTADOR',
#  'PINILLOS',
#  'MORALES',
#  'UNGUÍA',
#  'COTORRA',
#  'LOS PALMITOS',
#  'ALTO BAUDÓ',
#  'ORTEGA',
#  'GALERAS',
#  'MAHATES',
#  'SOPETRÁN',
#  'SANTA MARÍA',
#  'GUARANDA',
#  'NUEVA GRANADA',
#  'SANTO TOMÁS',
#  'MITÚ',
#  'CHIGORODÓ',
#  'SANTA ROSA',
#  'CAMPOALEGRE',
#  'ALTOS DEL ROSARIO',
#  'SALAMINA',
#  'TIBÚ',
#  'MAJAGUAL',
#  'EL BAGRE',
#  'TORIBÍO',
#  'SAN JUAN NEPOMUCENO',
#  'SANTA ROSALÍA',
#  'PUERTO RICO',
#  'PROVIDENCIA',
#  'TELLO',
#  'SABANAGRANDE',
#  'MARGARITA',
#  'LA ESPERANZA',
#  'ROVIRA',
#  'SAN ANDRÉS DE TUMACO',
#  'PLATO',
#  'FUNES',
#  'SUCRE',
#  'GIGANTE',
#  'PUERTO SANTANDER',
#  'PUENTE NACIONAL',
#  'CUMARIBO',
#  'SAN CRISTÓBAL',
#  'MANAURE BALCÓN DEL CESAR',
#  'PEQUE',
#  'DISTRACCIÓN',
#  'EL PIÑÓN',
#  'LA VEGA',
#  'MOMPÓS',
#  'BARRANCO DE LOBA',
#  'ALGARROBO',
#  'GÁMBITA',
#  'EL ROBLE',
#  'VALLE DE SAN JOSÉ',
#  'TENERIFE',
#  'MOMIL',
#  'SILVIA',
#  'ALBÁN',
#  'YOLOMBÓ',
#  'CÓRDOBA',
#  'LA MONTAÑITA',
#  'SAN VICENTE DEL CAGUÁN',
#  'LIBORINA',
#  'CURILLO',
#  'TURBO',
#  'ENTRERRÍOS',
#  'SAN MARTÍN DE LOBA',
#  'BUENAVISTA',
#  'ANSERMANUEVO',
#  'FUENTEDEORO',
#  'SAN PABLO DE BORBUR',
#  'SAN ANDRÉS DE SOTAVENTO',
#  'ARACATACA',
#  'DIBULLA',
#  'ZONA BANANERA',
#  'TORO',
#  'PIOJÓ',
#  'EL BANCO',
#  nan,
#  'EL PEÑÓN',
#  'SAN JERÓNIMO',
#  'CERRITO',
#  'CAUCASIA',
#  'FRONTINO',
#  'SUPÍA',
#  'QUIMBAYA',
#  'ASTREA',
#  'TALAIGUA NUEVO',
#  'MANATÍ',
#  'JURADÓ',
#  'TUBARÁ',
#  'OVEJAS',
#  'LURUACO',
#  'MANAURE',
#  'SAN JUAN DEL CESAR',
#  'PURIFICACIÓN',
#  'POLICARPA',
#  'CHINÚ',
#  'LA GLORIA',
#  'BECERRIL',
#  'GUALMATÁN',
#  'PUEBLOVIEJO',
#  'CHIMICHAGUA',
#  'LETICIA',
#  'CALAMAR',
#  'TURBANÁ',
#  'SOLITA',
#  'CUASPÚD',
#  'FORTUL',
#  'EL DONCELLO',
#  'LA TOLA',
#  'BAJO BAUDÓ',
#  'CICUCO',
#  'CARTAGENA DEL CHAIRÁ',
#  'PUERTO ESCONDIDO',
#  'COVEÑAS',
#  'SAN PEDRO DE URABÁ',
#  'TOGÜÍ',
#  'ARBOLETES',
#  'BOJAYÁ',
#  'SAN BERNARDO DEL VIENTO',
#  'SAN MARTÍN',
#  'PIAMONTE',
#  'TÁMARA',
#  'HATO COROZAL',
#  'MAGÜÍ',
#  'PUERTO LEGUÍZAMO',
#  'SAN SEBASTIÁN',
#  'PINCHOTE',
#  'CHIRIGUANÁ',
#  'GUAMAL',
#  'VIGÍA DEL FUERTE',
#  'NATAGAIMA',
#  'PUERTO NARIÑO',
#  'LA PRIMAVERA',
#  'CUCUTILLA',
#  'PIVIJAY',
#  'SANTA FÉ DE ANTIOQUIA',
#  'CHAPARRAL',
#  'ZARAGOZA',
#  'ESPINAL',
#  'BARRANCO MINAS',
#  'ATRATO',
#  'LA JAGUA DE IBIRICO',
#  'NECOCLÍ',
#  'LOS CÓRDOBAS',
#  'CONVENCIÓN',
#  'SILVANIA',
#  'TUTA',
#  'SANTA ROSA DE VITERBO',
#  'GUAITARILLA',
#  'MALLAMA',
#  'JARDÍN',
#  'ABRIAQUÍ',
#  'QUINCHÍA',
#  'UBALÁ',
#  'ZAPAYÁN',
#  'CALOTO',
#  'SAN BENITO ABAD',
#  'TAMALAMEQUE',
#  'MOÑITOS',
#  'ISNOS',
#  'ALGECIRAS',
#  'PALMITO',
#  'CUNDAY',
#  'PUERTO BERRÍO',
#  'GRAMALOTE',
#  'TEORAMA',
#  'NOROSÍ',
#  'BARBACOAS',
#  'AQUITANIA',
#  'PURÍSIMA DE LA CONCEPCIÓN',
#  'SIBUNDOY',
#  'TAMINANGO',
#  'INZÁ',
#  'GACHANCIPÁ',
#  'TARAZÁ',
#  'SATIVANORTE',
#  'BERBEO',
#  'LA PAZ',
#  'CHINÁCOTA',
#  'LA PLAYA',
#  'CUCUNUBÁ',
#  'GALÁN',
#  'TARQUI',
#  'PAYA',
#  'EL PEÑOL',
#  'TUCHÍN',
#  'VÉLEZ',
#  'SAN ESTANISLAO',
#  'SANTANA',
#  'YACUANQUER',
#  'AGUADAS',
#  'SAN PABLO',
#  'PAICOL',
#  'PÁEZ',
#  'LA CRUZ',
#  'LÉRIDA',
#  'TIMBÍO',
#  'ROSAS',
#  'JAMBALÓ',
#  'MONGUÍ',
#  'ABEJORRAL',
#  'MOTAVITA',
#  'SANTA HELENA DEL OPÓN',
#  'CHITA',
#  'LOS ANDES',
#  'SANTIAGO DE TOLÚ',
#  'PITAL',
#  'PUERTO GUZMÁN',
#  'CÁQUEZA',
#  'SAN VICENTE DE CHUCURÍ',
#  'LA UVITA',
#  'CÁCERES',
#  'SAN LORENZO',
#  'MORROA',
#  'VALLE DEL GUAMUEZ',
#  'SABOYÁ',
#  'PEÑOL',
#  'SANTA LUCÍA',
#  'SITIONUEVO',
#  'SAN JUAN DE BETULIA',
#  'SUAN',
#  'REPELÓN',
#  'ÁBREGO',
#  'ULLOA',
#  'PURACÉ',
#  'TÚQUERRES',
#  'CHOACHÍ',
#  'RONCESVALLES',
#  'ISTMINA',
#  'MOLAGAVITA',
#  'BELMIRA',
#  'EL DOVIO',
#  'GARAGOA',
#  'SOTARA',
#  'CISNEROS',
#  'CONDOTO',
#  'QUÍPAMA',
#  'CAIMITO',
#  'EL CARMEN',
#  'VIOTÁ',
#  'CARACOLÍ',
#  'ICONONZO',
#  'EL TAMBO',
#  'OLAYA',
#  'SABANA DE TORRES',
#  'SAN ALBERTO',
#  'EL TARRA',
#  'MARQUETALIA',
#  'YACOPÍ',
#  'BUENOS AIRES',
#  'UNE',
#  'PARATEBUENO',
#  'HONDA',
#  'SAN JOSÉ DE PARE',
#  'TRUJILLO',
#  'ÚMBITA',
#  'NUEVO COLÓN',
#  'SIACHOQUE',
#  'CASTILLA LA NUEVA',
#  'VEGACHÍ',
#  'ARAUQUITA',
#  'GONZÁLEZ',
#  'SAN AGUSTÍN',
#  'NOBSA',
#  'ROBERTO PAYÁN',
#  'SAN JACINTO',
#  'PAIPA',
#  'POLONUEVO',
#  'VENTAQUEMADA',
#  'SARDINATA',
#  'CHARALÁ',
#  'LÍBANO',
#  'TOCA',
#  'ÍQUIRA',
#  'VILLAVIEJA',
#  'SAN ANDRÉS DE CUERQUÍA',
#  'CRAVO NORTE',
#  'CANALETE',
#  'YONDÓ',
#  'COROZAL',
#  'GACHALÁ',
#  'LOS SANTOS',
#  'SAN CARLOS DE GUAROA',
#  'MOGOTES',
#  'OSPINA',
#  'MELGAR',
#  'SAN PEDRO DE CARTAGO',
#  'CHITAGÁ',
#  'TIMBIQUÍ',
#  'SAMACÁ',
#  'RAMIRIQUÍ',
#  'PUERTO BOYACÁ',
#  'PUEBLO BELLO',
#  'VILLA CARO',
#  'ATACO',
#  'SALAZAR',
#  'CUMBITARA',
#  'SAN CARLOS',
#  'SESQUILÉ',
#  'UBAQUE',
#  'SORACÁ',
#  'VILLARRICA',
#  'SANTA ROSA DEL SUR',
#  'OTANCHE',
#  'CIMITARRA',
#  'COROMORO',
#  'PANQUEBA',
#  'TOPAIPÍ',
#  'PUEBLORRICO',
#  'SIMIJACA',
#  'TIQUISIO',
#  'MURILLO',
#  'FÚQUENE',
#  'COLÓN',
#  'USIACURÍ',
#  'FLANDES',
#  'CHISCAS',
#  'GAMARRA',
#  'ANDES',
#  'ANORÍ',
#  'CURITÍ',
#  'MILÁN',
#  'PÁRAMO',
#  'TIBIRITA',
#  'PUERTO TRIUNFO',
#  'NECHÍ',
#  'EL TABLÓN DE GÓMEZ',
#  'TENZA',
#  'SAN ZENÓN',
#  'PAUNA',
#  'EL COPEY',
#  'OCAMONTE',
#  'SALADOBLANCO',
#  'CÁCHIRA',
#  'PAJARITO',
#  'SAN ANTONIO',
#  'EL PLAYÓN',
#  'SAN MIGUEL',
#  'PIEDRAS',
#  'SILOS',
#  'RÍO IRÓ',
#  'SAN CALIXTO',
#  'COLOSÓ',
#  'SUPATÁ',
#  'GACHANTIVÁ',
#  'FIRAVITOBA',
#  'LA ARGENTINA',
#  'SEGOVIA',
#  'NORCASIA',
#  'LENGUAZAQUE',
#  'EL COCUY',
#  'LANDÁZURI',
#  'BARICHARA',
#  'HOBO',
#  'PUERTO CONCORDIA',
#  'ARATOCA',
#  'QUEBRADANEGRA',
#  'MANÍ',
#  'SAN CAYETANO',
#  'MONTEBELLO',
#  'SAN ROQUE',
#  'SAN JOAQUÍN',
#  'CHIVOLO',
#  'SÁCHICA',
#  'VILLETA',
#  'SANTA BÁRBARA DE PINTO',
#  'MONIQUIRÁ',
#  'TIBANÁ',
#  'PUERTO CAICEDO',
#  'QUIPILE',
#  'PEDRAZA',
#  'PALERMO',
#  'MISTRATÓ',
#  'VILLA DE LEYVA',
#  'MIRAFLORES',
#  'PASCA',
#  'LA BELLEZA',
#  'REMOLINO',
#  'RAGONVALIA',
#  'SONSÓN',
#  'NEMOCÓN',
#  'RECETOR',
#  'AGUA DE DIOS',
#  'TIMANÁ',
#  'ARBOLEDA',
#  'SUSA',
#  'LA SIERRA',
#  'ARROYOHONDO',
#  'COVARACHÍA',
#  'EL CAIRO',
#  'JENESANO',
#  'PUERTO CARREÑO',
#  'GUAYATÁ',
#  'RÁQUIRA',
#  'EL ESPINO',
#  'TASCO',
#  'CAJAMARCA',
#  'CHIPAQUE',
#  'VILLAPINZÓN',
#  'TIPACOQUE',
#  'TURMEQUÉ',
#  'CAÑASGORDAS',
#  'BELALCÁZAR',
#  'GUÁTICA',
#  'LA PEDRERA',
#  'FOSCA',
#  'CHIPATÁ',
#  'CARCASÍ',
#  'SAN JOSÉ DEL FRAGUA',
#  'NUNCHÍA',
#  'HELICONIA',
#  'EL CARMEN DE ATRATO',
#  'ANZÁ',
#  'PAZ DE RÍO',
#  'TOCAIMA',
#  'BETANIA',
#  'MORELIA',
#  'FRESNO',
#  'VILLAGARZÓN',
#  'CLEMENCIA',
#  'JERICÓ',
#  'TADÓ',
#  'OBANDO',
#  'SAN LUIS DE SINCÉ',
#  'LLORÓ',
#  'VALPARAÍSO',
#  'RÍO VIEJO',
#  'ELÍAS',
#  'ARGELIA',
#  'SAN ANTONIO DEL TEQUENDAMA',
#  'GAMA',
#  'RÍO DE ORO',
#  'VILLAGÓMEZ',
#  'LA TEBAIDA',
#  'GUAYABETAL',
#  'MACANAL',
#  'URRAO',
#  'AIPE',
#  'AGRADO',
#  'BAGADÓ',
#  'PALMAR DE VARELA',
#  'BAHÍA SOLANO',
#  'SAN RAFAEL',
#  'ALCALÁ',
#  'VIRACACHÁ',
#  'LA JAGUA DEL PILAR',
#  'EL ROSARIO',
#  'CARMEN DE CARUPA',
#  'CAPITANEJO',
#  'CIÉNEGA',
#  'SIMACOTA',
#  'GÉNOVA',
#  'CHINAVITA',
#  'PRADO',
#  'TENA',
#  'RISARALDA',
#  'MEDIO BAUDÓ',
#  'TARAPACÁ',
#  'OROCUÉ',
#  'SALDAÑA',
#  'FÓMEQUE',
#  'AMALFI',
#  'SANTIAGO',
#  'SAMANIEGO',
#  'PIJAO',
#  'GUACA',
#  'GUAYABAL DE SÍQUIMA',
#  'LABATECA',
#  'APÍA',
#  'SANTA CATALINA',
#  'CAROLINA',
#  'DABEIBA',
#  'SAN JACINTO DEL CAUCA',
#  'SAN JOSÉ DE URÉ',
#  'SAN JOSÉ DE MIRANDA',
#  'EL LITORAL DEL SAN JUAN',
#  'BOCHALEMA',
#  'ENCISO',
#  'SAN JUAN DE RIOSECO',
#  'URUMITA',
#  'ANGOSTURA',
#  'FRANCISCO PIZARRO',
#  'RÍO QUITO',
#  'MUZO',
#  'MATANZA',
#  'EL RETORNO',
#  'DOLORES',
#  'EL MOLINO',
#  'ANZOÁTEGUI',
#  'SOPLAVIENTO',
#  'CUBARÁ',
#  'VENECIA',
#  'CHACHAGÜÍ',
#  'LA LLANADA',
#  'VERGARA',
#  'SEVILLA',
#  'GUASCA',
#  'SIMITÍ',
#  'PALESTINA',
#  'CUMARAL',
#  'EL ÁGUILA',
#  'CASABIANCA',
#  'LINARES',
#  'CAREPA',
#  'NEIRA',
#  'MONTERREY',
#  'RIOBLANCO',
#  'PÁCORA',
#  'CAICEDO',
#  'ALVARADO',
#  'CIUDAD BOLÍVAR',
#  'CÓMBITA',
#  'ANOLAIMA',
#  'MEDINA',
#  'MARMATO',
#  'GÜEPSA',
#  'SASAIMA',
#  'GÓMEZ PLATA',
#  'ALEJANDRÍA',
#  'SUÁREZ',
#  'TARSO',
#  'AMAGÁ',
#  'PADILLA',
#  'YALÍ',
#  'APULO',
#  'CAMPAMENTO',
#  'YAGUARÁ',
#  'PENSILVANIA',
#  'FILADELFIA',
#  'MARULANDA',
#  'EL CARMEN DE CHUCURÍ',
#  'COELLO',
#  'ARANZAZU',
#  'COPER',
#  'LA MACARENA',
#  'PUERTO NARE',
#  'SALGAR',
#  'SOATÁ',
#  'PISBA',
#  'CHIMÁ',
#  'OIBA',
#  'MARSELLA',
#  'GIRALDO',
#  'LA MERCED',
#  'TERUEL',
#  'ALMEIDA',
#  'SAN FERNANDO',
#  'TÁMESIS',
#  'SANTUARIO',
#  'BITUIMA',
#  'URAMITA',
#  'HISPANIA',
#  'ARENAL',
#  'PUERTO PARRA',
#  'LEIVA',
#  'SAN MIGUEL DE SEMA',
#  'CÉRTEGUI',
#  'GUATEQUE',
#  'PIJIÑO DEL CARMEN',
#  'LA CHORRERA',
#  'CONSACÁ',
#  'PUERTO LLERAS',
#  'ZAMBRANO',
#  'LA PEÑA',
#  'SALENTO',
#  'VALDIVIA',
#  'GUATAPÉ',
#  'CONCEPCIÓN',
#  'CAPARRAPÍ',
#  'BRICEÑO',
#  'TONA',
#  'OPORAPA',
#  'TÓPAGA',
#  'MAPIRIPÁN',
#  'LA CELIA',
#  'MONGUA',
#  'NUQUÍ',
#  'ARBOLEDAS',
#  'SOTAQUIRÁ',
#  'BELÉN DE LOS ANDAQUÍES',
#  'SAN LUIS DE PALENQUE',
#  'NÓVITA',
#  'SAN FELIPE',
#  'GACHETÁ',
#  'PUERTO SALGAR',
#  'MEDIO SAN JUAN',
#  'GÁMEZA',
#  'VALLE DE SAN JUAN',
#  'NILO',
#  'TIBASOSA',
#  'CACHIPAY',
#  'QUETAME',
#  'EL CANTÓN DEL SAN PABLO',
#  'SAN MATEO',
#  'LA SALINA',
#  'ÚTICA',
#  'CONTRATACIÓN',
#  'CUCAITA',
#  'PALMAR',
#  'CHÍQUIZA',
#  'BURITICÁ',
#  'EL GUAMO',
#  'NÁTAGA',
#  'PESCA',
#  'TITIRIBÍ',
#  'VENADILLO',
#  'SAPUYES',
#  'LA PALMA',
#  'NIMAIMA',
#  'SAN JOSÉ',
#  'TINJACÁ',
#  'SANTACRUZ',
#  'SAN JOSÉ DE LA MONTAÑA',
#  'SAN BENITO',
#  'CARURÚ',
#  'EL CHARCO',
#  'GUATAVITA',
#  'ARCABUCO',
#  'ZETAQUIRA',
#  'GUATAQUÍ',
#  'MERCADERES',
#  'SAN JUAN DE ARAMA',
#  'SUTATAUSA',
#  'SOLANO',
#  'LA PINTADA',
#  'TESALIA',
#  'BELÉN',
#  'ZIPACÓN',
#  'HERVEO',
#  'CHITARAQUE',
#  'CARMEN DE APICALÁ',
#  'AGUADA',
#  'TAUSA',
#  'UNIÓN PANAMERICANA',
#  'SAN LUIS DE GACENO',
#  'SOCHA',
#  'TARAIRA',
#  'GUACAMAYAS',
#  'CHIVATÁ',
#  'SURATÁ',
#  'EL DORADO',
#  'ANGELÓPOLIS',
#  'AMBALEMA',
#  'CARMEN DEL DARIÉN',
#  'VIANÍ',
#  'SORA',
#  'TUTAZÁ',
#  'DURANIA',
#  'CONTADERO',
#  'EL CALVARIO',
#  'PUERTO RONDÓN',
#  'BARRANCA DE UPÍA',
#  'MANTA',
#  'LÓPEZ DE MICAY',
#  'FLORIÁN',
#  'MIRITÍ - PARANÁ',
#  'CERINZA',
#  'CONFINES',
#  'JERUSALÉN',
#  'GUTIÉRREZ',
#  'GÜICÁN DE LA SIERRA',
#  'PAMPLONITA',
#  'CHAGUANÍ',
#  'MARIPÍ',
#  'HACARÍ',
#  'PULÍ',
#  'SAN JUANITO',
#  'SAN JOSÉ DEL PALMAR',
#  'SANTA SOFÍA',
#  'SUTAMARCHÁN',
#  'JORDÁN',
#  'JUNÍN',
#  'CARAMANTA',
#  'CHIMA',
#  'OICATÁ',
#  'VILLAHERMOSA',
#  'LA CAPILLA',
#  'TIBACUY',
#  'MACARAVITA',
#  'GUAVATÁ',
#  'PANDI',
#  'CHIVOR',
#  'TUNUNGUÁ',
#  'ACANDÍ',
#  'BARAYA',
#  'CÁCOTA',
#  'SAN EDUARDO',
#  'EL GUACAMAYO',
#  'FLORESTA',
#  'CHÁMEZA',
#  'CEPITÁ',
#  'SUTATENZA',
#  'BUSBANZÁ',
#  'PAIME',
#  ...]

# %% [markdown]
# ### Columna FAMI_ESTRATOVIVIENDA

# %%
# generar conteo de registros por valor único en la columna FAMI_ESTRATOVIVIENDAA que hace referencia al estrato de la vivienda de los estudiantes.

df_acumulado_saber_11['FAMI_ESTRATOVIVIENDA'].value_counts()
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 2      140626
# Estrato 1      115338
# Estrato 3       83627
# -               24541
# Estrato 4       21686
# Sin Estrato     13558
# Estrato 5        8511
# Estrato 6        5095
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                '-'             : 'No sabe',
                'Estrato 1'     : '1',
                'Estrato 2'     : '2',
                'Estrato 3'     : '3',
                'Estrato 4'     : '4',
                'Estrato 5'     : '5',
                'Estrato 6'     : '6',
                'Sin Estrato'   : 'No sabe'
}

# Implementar la función .replace
df_acumulado_saber_11['FAMI_ESTRATOVIVIENDA'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['FAMI_ESTRATOVIVIENDA'].value_counts()
# Out:
# <ipython-input-44-21c84734e53b>:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['FAMI_ESTRATOVIVIENDA'].replace(replace_dict, inplace=True)
# FAMI_ESTRATOVIVIENDA
# 2          140626
# 1          115338
# 3           83627
# No sabe     38099
# 4           21686
# 5            8511
# 6            5095
# Name: count, dtype: int64

# %% [markdown]
# ### FAMI_PERSONASHOGAR

# %%
df_acumulado_saber_11['FAMI_PERSONASHOGAR'].value_counts()
# Out:
# FAMI_PERSONASHOGAR
# 3 a 4            197169
# 5 a 6            126894
# 7 a 8             32808
# 1 a 2             30882
# 9 o más           12918
# -                  5509
# Sin Respuesta       713
# Name: count, dtype: int64

# %% [markdown]
# Reto: ¿Qué opciones/acciones propones para los fami_personashogar?

# %% [markdown]
# ### FAMI_CUARTOSHOGAR

# %%
df_acumulado_saber_11['FAMI_CUARTOSHOGAR'].value_counts()
# Out:
# FAMI_CUARTOSHOGAR
# Tres             157968
# Dos              140447
# Cuatro            54631
# Uno               20806
# Cinco             16900
# Seis o mas         9180
# -                  7746
# Sin respuesta       611
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    'Uno'               : '1',
                    'Dos'               : '2',
                    'Tres'              : '3',
                    'Cuatro'            : '4',
                    'Cinco'             : '5',
                    'Seis o mas'        : '6',
                    '-'                 : 'No responde',
                    'Sin respuesta'     : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['FAMI_CUARTOSHOGAR'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['FAMI_CUARTOSHOGAR'].value_counts()
# Out:
# <ipython-input-47-5149209a92d7>:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['FAMI_CUARTOSHOGAR'].replace(replace_dict, inplace=True)
# FAMI_CUARTOSHOGAR
# 3              157968
# 2              140447
# 4               54631
# 1               20806
# 5               16900
# 6                9180
# No responde      8357
# Name: count, dtype: int64

# %% [markdown]
# ### FAMI_NUMLIBROS

# %%
df_acumulado_saber_11['FAMI_NUMLIBROS'].value_counts()
# Out:
# FAMI_NUMLIBROS
# 0 A 10 LIBROS        152212
# 11 A 25 LIBROS       115673
# 26 A 100 LIBROS       82454
# MÁS DE 100 LIBROS     29248
# -                     27204
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '0 A 10 LIBROS'     : '0-10',
                    '11 A 25 LIBROS'    : '11-25',
                    '26 A 100 LIBROS'   : '26-100',
                    'MÁS DE 100 LIBROS' : '>100',
                    '-'                 : 'No sabe'
                }

# Implementar la función .replace
df_acumulado_saber_11['FAMI_NUMLIBROS'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['FAMI_NUMLIBROS'].value_counts()
# Out:
# <ipython-input-49-0041ae372572>:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['FAMI_NUMLIBROS'].replace(replace_dict, inplace=True)
# FAMI_NUMLIBROS
# 0-10       152212
# 11-25      115673
# 26-100      82454
# >100        29248
# No sabe     27204
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_DEDICACIONLECTURADIARIA

# %%
df_acumulado_saber_11['ESTU_DEDICACIONLECTURADIARIA'].value_counts()
# Out:
# ESTU_DEDICACIONLECTURADIARIA
# 30 minutos o menos            150096
# Entre 30 y 60 minutos         108957
# No leo por entretenimiento     73575
# Entre 1 y 2 horas              41526
# -                              23544
# Más de 2 horas                 14840
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '30 minutos o menos'            : '<30',
                    'Entre 30 y 60 minutos'         : '30-60',
                    'Entre 1 y 2 horas'             : '1h-2h',
                    'Más de 2 horas'                : '>2h',
                    'No leo por entretenimiento'    : 'No lee',
                    '-'                             : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_DEDICACIONLECTURADIARIA'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_DEDICACIONLECTURADIARIA'].value_counts()
# Out:
# <ipython-input-51-bd5c55a2e5b8>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['ESTU_DEDICACIONLECTURADIARIA'].replace(replace_dict, inplace=True)
# ESTU_DEDICACIONLECTURADIARIA
# <30            150096
# 30-60          108957
# No lee          73575
# 1h-2h           41526
# No responde     23544
# >2h             14840
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_DEDICACIONINTERNET

# %%
df_acumulado_saber_11['ESTU_DEDICACIONINTERNET'].value_counts()
# Out:
# ESTU_DEDICACIONINTERNET
# Entre 1 y 3 horas        120335
# Entre 30 y 60 minutos    100907
# Más de 3 horas            77847
# 30 minutos o menos        66630
# No Navega Internet        22396
# -                          3289
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '30 minutos o menos'            : '<30',
                    'Entre 30 y 60 minutos'         : '30-60',
                    'Entre 1 y 3 horas'             : '1h-3h',
                    'Más de 3 horas'                : '>3h',
                    'No Navega Internet'            : 'No navega',
                    '-'                             : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_DEDICACIONINTERNET'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_DEDICACIONINTERNET'].value_counts()
# Out:
# <ipython-input-53-bda681960337>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['ESTU_DEDICACIONINTERNET'].replace(replace_dict, inplace=True)
# ESTU_DEDICACIONINTERNET
# 1h-3h          120335
# 30-60          100907
# >3h             77847
# <30             66630
# No navega       22396
# No responde      3289
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_HORASSEMANATRABAJA

# %%
df_acumulado_saber_11['ESTU_HORASSEMANATRABAJA'].value_counts()
# Out:
# ESTU_HORASSEMANATRABAJA
# 0                      267465
# Menos de 10 horas       73371
# Entre 11 y 20 horas     31732
# Más de 30 horas         15840
# -                       12548
# Entre 21 y 30 horas     11767
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '0'                     : '0',
                    'Menos de 10 horas'     : '<10',
                    'Entre 11 y 20 horas'   : '11-20',
                    'Entre 21 y 30 horas'   : '21-30',
                    'Más de 30 horas'       : '>30',
                    '-'                     : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_HORASSEMANATRABAJA'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_HORASSEMANATRABAJA'].value_counts()
# Out:
# <ipython-input-55-b067823aec55>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['ESTU_HORASSEMANATRABAJA'].replace(replace_dict, inplace=True)
# ESTU_HORASSEMANATRABAJA
# 0              267465
# <10             73371
# 11-20           31732
# >30             15840
# No responde     12548
# 21-30           11767
# Name: count, dtype: int64

# %% [markdown]
# ### ESTU_TIPOREMUNERACION

# %%
df_acumulado_saber_11['ESTU_TIPOREMUNERACION'].value_counts()
# Out:
# ESTU_TIPOREMUNERACION
# No                           283544
# Si, en efectivo              103611
# Si, en especie                 6466
# Si, en efectivo y especie      5621
# -                              2506
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'Prefiero no responder'
                }

# Implementar la función .replace
df_acumulado_saber_11['ESTU_TIPOREMUNERACION'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['ESTU_TIPOREMUNERACION'].value_counts()
# Out:
# ESTU_TIPOREMUNERACION
# No                           726749
# Si, en efectivo              284066
# Si, en especie                20379
# Si, en efectivo y especie     17261
# Prefiero no responder          3250
# Name: count, dtype: int64

# %% [markdown]
# ### COLE_BILINGUE

# %%
df_acumulado_saber_11['COLE_BILINGUE'].value_counts()
# Out:
# COLE_BILINGUE
# N    339171
# -     66213
# S      7618
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'No responde'
                }

# Implementar la función .replace
df_acumulado_saber_11['COLE_BILINGUE'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['COLE_BILINGUE'].value_counts()
# Out:
# <ipython-input-58-c9228132155b>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['COLE_BILINGUE'].replace(replace_dict, inplace=True)
# COLE_BILINGUE
# N              339171
# No responde     66213
# S                7618
# Name: count, dtype: int64

# %% [markdown]
# ### COLE_CARACTER

# %%
df_acumulado_saber_11['COLE_CARACTER'].value_counts()
# Out:
# COLE_CARACTER
# ACADÉMICO            220117
# TÉCNICO/ACADÉMICO    131967
# TÉCNICO               43927
# NO APLICA              5117
# -                      1920
# Name: count, dtype: int64

# %%
# Reemplazar valores de registros para el ahorro de recurso compuracional

# Crear un diccionario
replace_dict = {
                    '-' : 'NO RESPONDE'
                }

# Implementar la función .replace
df_acumulado_saber_11['COLE_CARACTER'].replace(replace_dict, inplace=True)
df_acumulado_saber_11['COLE_CARACTER'].value_counts()
# Out:
# <ipython-input-60-96a09459ebe7>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_acumulado_saber_11['COLE_CARACTER'].replace(replace_dict, inplace=True)
# COLE_CARACTER
# ACADÉMICO            220117
# TÉCNICO/ACADÉMICO    131967
# TÉCNICO               43927
# NO APLICA              5117
# NO RESPONDE            1920
# Name: count, dtype: int64

# %% [markdown]
# `Reto: ¿Qué opciones/acciones propones para los COLE_CARACTER referente a los campos TÉCNICO Y TÉCNICO/ACADÉMICO?`

# %% [markdown]
# ### COLE_NATURALEZA

# %%
df_acumulado_saber_11['COLE_NATURALEZA'].value_counts()
# Out:
# COLE_NATURALEZA
# OFICIAL       299700
# NO OFICIAL    113302
# Name: count, dtype: int64

# %% [markdown]
# ### COLE_JORNADA

# %%
df_acumulado_saber_11['COLE_JORNADA'].value_counts()
# Out:
# COLE_JORNADA
# MAÑANA      191173
# COMPLETA     73052
# UNICA        48410
# TARDE        43444
# SABATINA     30554
# NOCHE        26368
# Name: count, dtype: int64

# %%
# Exportar el dataframe acumulado_saber_11 en formato CSV

df_acumulado_saber_11.to_csv('acumulado_saber_11.csv', index=False)

print(f"El archivo ha sido exportado exitosamente.")
# Out:
# El archivo ha sido exportado exitosamente.

# %% [markdown]
# # Conclusiones

# %% [markdown]
# El análisis técnico de limpieza de datos es una tarea esencial en cualquier proyecto de análisis de datos, ya que permite obtener datos de alta calidad y precisión. A partir de la limpieza de datos realizada, se pueden obtener diversas conclusiones, entre ellas:
#
# - No se identificaron muchos valores atípicos, en algunas columnas, solo habían registros que no indicaban una respuesta concreta (Si o No) al titulo de la columna.
#
# - Se mejoro la calidad del DataFrame, la limpieza permitio eliminar inconsistencias y actualizar algunas. Con datos de alta calidad, se pueden obtener resultados más precisos y confiables.
#
# - Con dicha limpieza, se asegura integridad de los datos, este análisis técnico de limpieza de datos ya permitio ayudar a garantizar la integridad de los datos, asegurando que estos se mantengan precisos y confiables para posteriores actividades como pueden ser construcciones de analisis exploratorios de datos, pruebas de hipótesis, construcción de tableros de analitica, modelos predictivos, entre otros.
#
# - También se mininizo el riesgo de errores para fututos análisis, al limpiar los datos antes de analizarlos, se puede reducir el riesgo de errores en el análisis, lo que puede llevar a conclusiones incorrectas.
#
# El Dataframe "acumulado_saber_11" se encuentra en condiciones para seguir con diferentes actividades y técnicas que la Ciencia de Datos permite.

# %% [markdown]
# # Retos abiertos

# %% [markdown]
# 1.	Revisar y ajustar las siguientes columnas:
#
# -	ESTU_FECHANACIMIENTO:
# -	FAMI_EDUCACIONPADRE: Generar una “categoría” para agrupar los registros de la columna.
# -	FAMI_EDUCACIONMADRE: Generar una “categoría” para agrupar los registros de la columna.
# -	FAMI_TRABAJOLABORPADRE: Generar una “categoría” para agrupar los registros de la columna.
# -	FAMI_TRABAJOLABORMADRE: Generar una “categoría” para agrupar los registros de la columna.

# %%
valores_educacion_padre = df_acumulado_saber_11['FAMI_EDUCACIONPADRE'].unique()
valores_educacion_padre
# Out:
# array(['Educación profesional completa', 'Postgrado',
#        'Secundaria (Bachillerato) completa',
#        'Técnica o tecnológica incompleta', 'Sin respuesta',
#        'Primaria incompleta', 'Secundaria (Bachillerato) incompleta',
#        'Técnica o tecnológica completa', 'Primaria completa', 'No sabe',
#        'No Aplica', 'Ninguno', 'Educación profesional incompleta', '-',
#        nan], dtype=object)

# %%
def clasificar_educacion(educacion):
    if educacion in ['Sin respuesta', 'Primaria incompleta', 'Secundaria (Bachillerato) incompleta',
                     'Técnica o tecnológica incompleta', 'No sabe', 'No Aplica', 'Ninguno', '-']:
        return 'Ninguna educación'
    elif educacion in ['Primaria completa', 'Secundaria (Bachillerato) completa']:
        return 'Educación básica'
    elif educacion == 'Técnica o tecnológica completa':
        return 'Educación técnica'
    elif educacion in ['Educación profesional completa', 'Educación profesional incompleta']:
        return 'Educación profesional'
    elif educacion == 'Postgrado':
        return 'Postgrado'
    else:
        return np.nan  # Manejar valores no previstos

# Aplicar la función a la columna FAMI_EDUCACIONPADRE
df_acumulado_saber_11['Categoria_educacion'] = df_acumulado_saber_11['FAMI_EDUCACIONPADRE'].apply(clasificar_educacion)

#ver las nuevas categorías
df_acumulado_saber_11[['FAMI_EDUCACIONPADRE', 'Categoria_educacion']]
# Out:
#                        FAMI_EDUCACIONPADRE    Categoria_educacion
# 0           Educación profesional completa  Educación profesional
# 1                                Postgrado              Postgrado
# 2       Secundaria (Bachillerato) completa       Educación básica
# 3                                Postgrado              Postgrado
# 4           Educación profesional completa  Educación profesional
# ...                                    ...                    ...
# 412997                 Primaria incompleta      Ninguna educación
# 412998  Secundaria (Bachillerato) completa       Educación básica
# 412999                 Primaria incompleta      Ninguna educación
# 413000                   Primaria completa       Educación básica
# 413001  Secundaria (Bachillerato) completa       Educación básica
#
# [413002 rows x 2 columns]

# %%
valores_educacion_madre = df_acumulado_saber_11['FAMI_EDUCACIONMADRE'].unique()
valores_educacion_madre
# Out:
# array(['Educación profesional completa',
#        'Secundaria (Bachillerato) completa', 'Postgrado',
#        'Técnica o tecnológica incompleta', 'Sin respuesta',
#        'Primaria incompleta', 'Secundaria (Bachillerato) incompleta',
#        'Técnica o tecnológica completa', 'Primaria completa', 'No sabe',
#        'Educación profesional incompleta', 'Ninguno', 'No Aplica', nan,
#        '-'], dtype=object)

# %%
valores_trabajo_Padre = df_acumulado_saber_11['FAMI_TRABAJOLABORPADRE'].unique()
valores_trabajo_Padre
# Out:
# array(['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)',
#        'Trabaja por cuenta propia (por ejemplo plomero, electricista)',
#        'Trabaja en el hogar, no trabaja o estudia',
#        'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)',
#        'Es operario de máquinas o conduce vehículos (taxita, chofer)',
#        'Sin respuesta',
#        'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc',
#        'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial',
#        'No aplica', 'Pensionado',
#        'Es vendedor o trabaja en atención al público', 'No sabe',
#        'Trabaja como personal de limpieza, mantenimiento, seguridad o construcción',
#        'Es agricultor, pesquero o jornalero', '-', nan], dtype=object)

# %%
def clasificar_trabajo(trabajo):
    if trabajo in ['Trabaja en el hogar, no trabaja o estudia', 'Sin respuesta', 'No aplica',
                   'No sabe', '-', np.nan]:
        return 'Sin trabajo'
    elif trabajo in ['Es personal de limpieza, mantenimiento, seguridad o construcción',
                     'Es operario de máquinas o conduce vehículos (taxita, chofer)',
                     'Es agricultor, pesquero o jornalero']:
        return 'Trabajo no calificado'
    elif trabajo in ['Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)',
                     'Es vendedor o trabaja en atención al público']:
        return 'Trabajo auxiliar'
    elif trabajo in ['Trabaja por cuenta propia (por ejemplo, plomero, electricista)',
                     'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc)',
                     'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial']:
        return 'Trabajo independiente'
    elif trabajo in ['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)', 'Pensionado']:
        return 'Profesional'
    else:
        return np.nan  # Manejar valores no previstos

# Aplicar la función a la columna FAMI_TRABAJOLABORPADRE
df_acumulado_saber_11['Categoria_trabajo'] = df_acumulado_saber_11['FAMI_TRABAJOLABORPADRE'].apply(clasificar_trabajo)

# ver las nuevas categorías
df_acumulado_saber_11[['FAMI_TRABAJOLABORPADRE', 'Categoria_trabajo']]
# Out:
#                                    FAMI_TRABAJOLABORPADRE  \
# 0       Trabaja como profesional (por ejemplo médico, ...
# 1       Trabaja como profesional (por ejemplo médico, ...
# 2       Trabaja por cuenta propia (por ejemplo plomero...
# 3       Trabaja como profesional (por ejemplo médico, ...
# 4               Trabaja en el hogar, no trabaja o estudia
# ...                                                   ...
# 412997                Es agricultor, pesquero o jornalero
# 412998                Es agricultor, pesquero o jornalero
# 412999                Es agricultor, pesquero o jornalero
# 413000                Es agricultor, pesquero o jornalero
# 413001  Tiene un trabajo de tipo auxiliar administrati...
#
#             Categoria_trabajo
# 0                 Profesional
# 1                 Profesional
# 2                         NaN
# 3                 Profesional
# 4                 Sin trabajo
# ...                       ...
# 412997  Trabajo no calificado
# 412998  Trabajo no calificado
# 412999  Trabajo no calificado
# 413000  Trabajo no calificado
# 413001       Trabajo auxiliar
#
# [413002 rows x 2 columns]

# %%
valores_trabajo_madre = df_acumulado_saber_11['FAMI_TRABAJOLABORMADRE'].unique()
valores_trabajo_madre
# Out:
# array(['Trabaja como profesional (por ejemplo médico, abogado, ingeniero)',
#        'Trabaja en el hogar, no trabaja o estudia',
#        'Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial',
#        'Tiene un trabajo de tipo auxiliar administrativo (por ejemplo, secretario o asistente)',
#        'Es vendedor o trabaja en atención al público', 'Sin respuesta',
#        'Es agricultor, pesquero o jornalero',
#        'Es operario de máquinas o conduce vehículos (taxita, chofer)',
#        'Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc',
#        'Trabaja como personal de limpieza, mantenimiento, seguridad o construcción',
#        'Trabaja por cuenta propia (por ejemplo plomero, electricista)',
#        'No sabe', 'Pensionado', 'No aplica', nan, '-'], dtype=object)
